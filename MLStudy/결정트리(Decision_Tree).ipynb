# %% [markdown]
# # 결정 트리(Decision Tree)
#
# * 분류와 회귀에 사용되는 지도 학습 방법
# * 데이터 특성으로 부터 추론된 결정 규칙을 통해 값을 예측
# * **if-then-else** 결정 규칙을 통해 데이터 학습
# * 트리의 깊이가 깊을 수록 복잡한 모델
# * 결정 트리 장점
#   * 이해와 해석이 쉽다
#   * 시각화가 용이하다
#   * 많은 데이터 전처리가 필요하지 않다
#   * 수치형과 범주형 데이터 모두를 다룰 수 있다
#   * ...

# %%
import pandas as pd
import numpy as np
import graphviz
import multiprocessing
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

# %%
from sklearn.datasets import load_iris, load_wine, load_breast_cancer
from sklearn.datasets import load_boston, load_diabetes
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ## 분류를 위한 데이터

# %% [markdown]
# ### 붓꽃 데이터

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 와인 데이터

# %%
wine = load_wine()

# %%
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
wine_df['target'] = wine.target
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  target
# 0                            3.92   1065.0       0
# 1                            3.40   1050.0       0
# 2                            3.17   1185.0       0
# 3                            3.45   1480.0       0
# 4                            2.93    735.0       0
# ..                            ...      ...     ...
# 173                          1.74    740.0       2
# 174                          1.56    750.0       2
# 175                          1.56    835.0       2
# 176                          1.62    840.0       2
# 177                          1.60    560.0       2
#
# [178 rows x 14 columns]

# %% [markdown]
# ### 유방암 데이터

# %%
cancer = load_breast_cancer()

# %%
cancer_df = pd.DataFrame(data=cancer.data, columns=cancer.feature_names)
cancer_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# ## 회귀를 위한 데이터

# %% [markdown]
# ### 보스턴 주택 가격 데이터

# %%
boston = load_boston()
# Out:
# C:\Users\rla02\miniconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
boston_df = pd.DataFrame(data=boston.data, columns=boston.feature_names)
boston_df['Target'] = boston.target
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ### 당뇨병 데이터

# %%
diabetes = load_diabetes()

# %%
diabetes_df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
diabetes_df['Target'] = diabetes.target
diabetes_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6  Target
# 0   -0.002592  0.019908 -0.017646   151.0
# 1   -0.039493 -0.068330 -0.092204    75.0
# 2   -0.002592  0.002864 -0.025930   141.0
# 3    0.034309  0.022692 -0.009362   206.0
# 4   -0.002592 -0.031991 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018118  0.044485   104.0
# 439 -0.011080 -0.046879  0.015491   132.0
# 440  0.026560  0.044528 -0.025930   220.0
# 441 -0.039493 -0.004220  0.003064    57.0
#
# [442 rows x 11 columns]

# %% [markdown]
# ## 분류 - `DecisionTreeClassifier()`
#
# * `DecisionTreeClassifier`는 분류를 위한 결정트리 모델
# * 두개의 배열 X, y를 입력 받음
#   * X는 [n_samples, n_features] 크기의 데이터 특성 배열
#   * y는 [n_samples] 크기의 정답 배열

# %%
X = [[0,0],[1,1]]
y = [0,1]

model = tree.DecisionTreeClassifier()
model = model.fit(X,y)

# %%
model.predict([[2.,2.]])
# Out:
# array([1])

# %%
model.predict_proba([[2.,2.]])
# Out:
# array([[0., 1.]])

# %% [markdown]
# ### 붓꽃 데이터 학습

# %% [markdown]
# #### 교차검증

# %% [markdown]
# ##### 전처리 없이 학습

# %%
model = DecisionTreeClassifier()

# %%
cross_val_score(
    estimator=model,
    X = iris.data, y=iris.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.96666667, 1.        ])

# %% [markdown]
# ##### 전처리 후 학습
# * 결정 트리는 규칙을 학습하기 때문에 전처리에 큰 영향을 받지 않는다.

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeClassifier()
)

# %%
cross_val_score(
    estimator=model,
    X = iris.data, y=iris.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 1.        , 1.        ])

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %%
model = DecisionTreeClassifier()
model.fit(iris.data, iris.target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %%
r = tree.export_text(decision_tree=model,
                    feature_names=iris.feature_names)
print(r)
# Out:
# |--- petal length (cm) <= 2.45
# |   |--- class: 0
# |--- petal length (cm) >  2.45
# |   |--- petal width (cm) <= 1.75
# |   |   |--- petal length (cm) <= 4.95
# |   |   |   |--- petal width (cm) <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- petal width (cm) >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- petal length (cm) >  4.95
# |   |   |   |--- petal width (cm) <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- petal width (cm) >  1.55
# |   |   |   |   |--- sepal length (cm) <= 6.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- sepal length (cm) >  6.95
# |   |   |   |   |   |--- class: 2
# |   |--- petal width (cm) >  1.75
# |   |   |--- petal length (cm) <= 4.85
# |   |   |   |--- sepal width (cm) <= 3.10
# |   |   |   |   |--- class: 2
# |   |   |   |--- sepal width (cm) >  3.10
# |   |   |   |   |--- class: 1
# |   |   |--- petal length (cm) >  4.85
# |   |   |   |--- class: 2

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'X[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz(decision_tree=model,
                               feature_names=iris.feature_names,
                               class_names=iris.target_names,
                               filled=True,rounded=True,
                               special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# #### 시각화

# %%
n_classes = 3
plot_colors = 'ryb'
plot_step = 0.02

# %% [markdown]
# ##### 결정 경계 시각화

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([[0,1],[0,2],[0,3],
                               [1,2],[1,3],[2,3]]):
    X = iris.data[:,pair]
    y = iris.target
    
    model = DecisionTreeClassifier()
    model = model.fit(X,y)
    
    plt.subplot(2,3,pairidx+1)
    
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1
    xx, yy = np.meshgrid(np.arange(x_min,x_max,plot_step),
                        np.arange(y_min,y_max,plot_step))
    plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap = plt.cm.RdYlBu)
    
    plt.xlabel(iris.feature_names[pair[0]])
    plt.ylabel(iris.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y == i)
        plt.scatter(X[idx,0],X[idx,1],c=color,label=iris.target_names[i],cmap=plt.cm.RdYlBu, edgecolors='b',s=15)
        
plt.suptitle('Decision surface')
plt.legend(loc='lower right',borderpad=0,handletextpad=0.5)
plt.axis('tight')
# Out:
# (0.0, 7.88, -0.9, 3.4800000000000044)

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 결정 경계의 변화 확인

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([[0,1],[0,2],[0,3],
                               [1,2],[1,3],[2,3]]):
    X = iris.data[:,pair]
    y = iris.target
    
    model = DecisionTreeClassifier(max_depth=2)
    model = model.fit(X,y)
    
    plt.subplot(2,3,pairidx+1)
    
    x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
    y_min, y_max = X[:,1].min()-1, X[:,1].max()+1
    xx, yy = np.meshgrid(np.arange(x_min,x_max,plot_step),
                        np.arange(y_min,y_max,plot_step))
    plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap = plt.cm.RdYlBu)
    
    plt.xlabel(iris.feature_names[pair[0]])
    plt.ylabel(iris.feature_names[pair[1]])
    
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y == i)
        plt.scatter(X[idx,0],X[idx,1],c=color,label=iris.target_names[i],cmap=plt.cm.RdYlBu, edgecolors='b',s=15)
        
plt.suptitle('Decision surface')
plt.legend(loc='lower right',borderpad=0,handletextpad=0.5)
plt.axis('tight')
# Out:
# (0.0, 7.88, -0.9, 3.4800000000000044)

# %% [markdown]
# ### 와인 데이터 학습

# %% [markdown]
# #### 교차 검증

# %% [markdown]
# ##### 전처리 없이 학습

# %% [markdown]
# ##### 전처리 후 학습

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %% [markdown]
# #### 시각화

# %% [markdown]
# ##### 결정 경계 시각화

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 결정 경계의 변화 확인

# %% [markdown]
# ### 유방암 데이터 학습

# %% [markdown]
# #### 교차 검증

# %% [markdown]
# ##### 전처리 없이 학습

# %% [markdown]
# ##### 전처리 후 학습

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %% [markdown]
# #### 시각화

# %% [markdown]
# ##### 결정 경계 시각화

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 결정 경계의 변화 확인

# %% [markdown]
# ## 회귀 - `DecisionTreeRegressor()`

# %% [markdown]
# ### 보스턴 주택 가격 데이터 학습

# %% [markdown]
# #### 교차 검증

# %% [markdown]
# ##### 전처리 없이 학습

# %%
model = DecisionTreeRegressor()

# %%
cross_val_score(
    estimator=model,
    X = boston.data, y=boston.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([ 0.61698919,  0.68817621,  0.63986533,  0.376165  , -1.78400027])

# %% [markdown]
# ##### 전처리 후 학습

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeRegressor()
)

# %%
cross_val_score(
    estimator=model,
    X = boston.data, y=boston.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([ 0.63631588,  0.42804952,  0.63599455,  0.36529796, -0.84812059])

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %%
model = DecisionTreeRegressor()
model.fit(boston.data, boston.target)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %%
print(tree.export_text(model))
# Out:
# |--- feature_5 <= 6.94
# |   |--- feature_12 <= 14.40
# |   |   |--- feature_7 <= 1.38
# |   |   |   |--- feature_12 <= 10.83
# |   |   |   |   |--- value: [50.00]
# |   |   |   |--- feature_12 >  10.83
# |   |   |   |   |--- value: [27.90]
# |   |   |--- feature_7 >  1.38
# |   |   |   |--- feature_5 <= 6.54
# |   |   |   |   |--- feature_12 <= 7.57
# |   |   |   |   |   |--- feature_9 <= 222.50
# |   |   |   |   |   |   |--- value: [28.70]
# |   |   |   |   |   |--- feature_9 >  222.50
# |   |   |   |   |   |   |--- feature_2 <= 5.48
# |   |   |   |   |   |   |   |--- feature_10 <= 19.95
# |   |   |   |   |   |   |   |   |--- feature_11 <= 393.33
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 3.90
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [21.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  3.90
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 23.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.70]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  23.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_11 >  393.33
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 19.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 31.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  31.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  19.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.20]
# |   |   |   |   |   |   |   |--- feature_10 >  19.95
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.31
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [20.70]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [20.60]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.31
# |   |   |   |   |   |   |   |   |   |--- value: [22.20]
# |   |   |   |   |   |   |--- feature_2 >  5.48
# |   |   |   |   |   |   |   |--- feature_1 <= 34.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 359.51
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 96.30
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.66
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [27.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.66
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [27.50]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  96.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.30]
# |   |   |   |   |   |   |   |   |--- feature_11 >  359.51
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.15
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 18.80
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.10]
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  18.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.15
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 278.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  278.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- feature_1 >  34.00
# |   |   |   |   |   |   |   |   |--- value: [29.10]
# |   |   |   |   |--- feature_12 >  7.57
# |   |   |   |   |   |--- feature_9 <= 208.00
# |   |   |   |   |   |   |--- feature_6 <= 69.25
# |   |   |   |   |   |   |   |--- feature_5 <= 6.15
# |   |   |   |   |   |   |   |   |--- value: [36.20]
# |   |   |   |   |   |   |   |--- feature_5 >  6.15
# |   |   |   |   |   |   |   |   |--- value: [29.60]
# |   |   |   |   |   |   |--- feature_6 >  69.25
# |   |   |   |   |   |   |   |--- feature_10 <= 18.45
# |   |   |   |   |   |   |   |   |--- value: [26.40]
# |   |   |   |   |   |   |   |--- feature_10 >  18.45
# |   |   |   |   |   |   |   |   |--- feature_6 <= 76.90
# |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |   |   |--- feature_6 >  76.90
# |   |   |   |   |   |   |   |   |   |--- value: [20.30]
# |   |   |   |   |   |--- feature_9 >  208.00
# |   |   |   |   |   |   |--- feature_5 <= 6.08
# |   |   |   |   |   |   |   |--- feature_6 <= 69.10
# |   |   |   |   |   |   |   |   |--- feature_7 <= 4.46
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.21
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.10]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.21
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 17.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  17.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_7 >  4.46
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.76
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.76
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 5.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  5.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- feature_6 >  69.10
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.03
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.30]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.03
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.56
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.50]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.56
# |   |   |   |   |   |   |   |   |   |   |--- value: [11.90]
# |   |   |   |   |   |   |--- feature_5 >  6.08
# |   |   |   |   |   |   |   |--- feature_12 <= 9.98
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.05
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.50]
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.05
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 33.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  33.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 9.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  9.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_12 >  9.98
# |   |   |   |   |   |   |   |   |--- feature_11 <= 197.52
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 84.38
# |   |   |   |   |   |   |   |   |   |   |--- value: [18.60]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  84.38
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.10]
# |   |   |   |   |   |   |   |   |--- feature_11 >  197.52
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 20.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  20.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 3.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  3.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- feature_5 >  6.54
# |   |   |   |   |--- feature_9 <= 269.00
# |   |   |   |   |   |--- feature_10 <= 17.85
# |   |   |   |   |   |   |--- feature_11 <= 393.41
# |   |   |   |   |   |   |   |--- feature_11 <= 392.41
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.67
# |   |   |   |   |   |   |   |   |   |--- value: [29.10]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.67
# |   |   |   |   |   |   |   |   |   |--- value: [30.10]
# |   |   |   |   |   |   |   |--- feature_11 >  392.41
# |   |   |   |   |   |   |   |   |--- feature_1 <= 80.00
# |   |   |   |   |   |   |   |   |   |--- value: [31.10]
# |   |   |   |   |   |   |   |   |--- feature_1 >  80.00
# |   |   |   |   |   |   |   |   |   |--- value: [31.60]
# |   |   |   |   |   |   |--- feature_11 >  393.41
# |   |   |   |   |   |   |   |--- feature_10 <= 16.25
# |   |   |   |   |   |   |   |   |--- value: [35.10]
# |   |   |   |   |   |   |   |--- feature_10 >  16.25
# |   |   |   |   |   |   |   |   |--- feature_6 <= 30.25
# |   |   |   |   |   |   |   |   |   |--- value: [33.10]
# |   |   |   |   |   |   |   |   |--- feature_6 >  30.25
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 4.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 4.43
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  4.43
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.40]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  4.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [32.00]
# |   |   |   |   |   |--- feature_10 >  17.85
# |   |   |   |   |   |   |--- feature_0 <= 0.03
# |   |   |   |   |   |   |   |--- value: [30.80]
# |   |   |   |   |   |   |--- feature_0 >  0.03
# |   |   |   |   |   |   |   |--- feature_11 <= 392.83
# |   |   |   |   |   |   |   |   |--- value: [26.60]
# |   |   |   |   |   |   |   |--- feature_11 >  392.83
# |   |   |   |   |   |   |   |   |--- feature_6 <= 25.65
# |   |   |   |   |   |   |   |   |   |--- value: [27.90]
# |   |   |   |   |   |   |   |   |--- feature_6 >  25.65
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 64.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.40]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  64.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [28.20]
# |   |   |   |   |--- feature_9 >  269.00
# |   |   |   |   |   |--- feature_4 <= 0.53
# |   |   |   |   |   |   |--- feature_4 <= 0.44
# |   |   |   |   |   |   |   |--- feature_6 <= 35.20
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.68
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.50]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.80]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.68
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 395.32
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [26.60]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [26.20]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  395.32
# |   |   |   |   |   |   |   |   |   |   |--- value: [28.00]
# |   |   |   |   |   |   |   |--- feature_6 >  35.20
# |   |   |   |   |   |   |   |   |--- feature_12 <= 8.43
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.80]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 17.45
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.30]
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  17.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_12 >  8.43
# |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |--- feature_4 >  0.44
# |   |   |   |   |   |   |   |--- feature_12 <= 7.05
# |   |   |   |   |   |   |   |   |--- feature_9 <= 301.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.48
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 8.41
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  8.41
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.60]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.48
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [29.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [29.90]
# |   |   |   |   |   |   |   |   |--- feature_9 >  301.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 4.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [31.50]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  4.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [29.80]
# |   |   |   |   |   |   |   |--- feature_12 >  7.05
# |   |   |   |   |   |   |   |   |--- feature_7 <= 3.90
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.73
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 73.65
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [29.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  73.65
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [30.10]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.73
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 74.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [26.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  74.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [27.50]
# |   |   |   |   |   |   |   |   |--- feature_7 >  3.90
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [27.10]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 396.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  396.24
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.90]
# |   |   |   |   |   |--- feature_4 >  0.53
# |   |   |   |   |   |   |--- feature_10 <= 17.10
# |   |   |   |   |   |   |   |--- feature_4 <= 0.54
# |   |   |   |   |   |   |   |   |--- value: [24.00]
# |   |   |   |   |   |   |   |--- feature_4 >  0.54
# |   |   |   |   |   |   |   |   |--- value: [28.70]
# |   |   |   |   |   |   |--- feature_10 >  17.10
# |   |   |   |   |   |   |   |--- feature_10 <= 20.60
# |   |   |   |   |   |   |   |   |--- feature_7 <= 3.32
# |   |   |   |   |   |   |   |   |   |--- value: [22.80]
# |   |   |   |   |   |   |   |   |--- feature_7 >  3.32
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 81.10
# |   |   |   |   |   |   |   |   |   |   |--- value: [23.70]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  81.10
# |   |   |   |   |   |   |   |   |   |   |--- value: [23.80]
# |   |   |   |   |   |   |   |--- feature_10 >  20.60
# |   |   |   |   |   |   |   |   |--- feature_2 <= 10.04
# |   |   |   |   |   |   |   |   |   |--- value: [21.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  10.04
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.40]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |--- feature_12 >  14.40
# |   |   |--- feature_0 <= 6.99
# |   |   |   |--- feature_4 <= 0.53
# |   |   |   |   |--- feature_7 <= 5.57
# |   |   |   |   |   |--- feature_6 <= 88.55
# |   |   |   |   |   |   |--- feature_11 <= 385.38
# |   |   |   |   |   |   |   |--- feature_12 <= 22.10
# |   |   |   |   |   |   |   |   |--- value: [24.40]
# |   |   |   |   |   |   |   |--- feature_12 >  22.10
# |   |   |   |   |   |   |   |   |--- value: [23.70]
# |   |   |   |   |   |   |--- feature_11 >  385.38
# |   |   |   |   |   |   |   |--- feature_4 <= 0.52
# |   |   |   |   |   |   |   |   |--- feature_7 <= 3.12
# |   |   |   |   |   |   |   |   |   |--- value: [23.10]
# |   |   |   |   |   |   |   |   |--- feature_7 >  3.12
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.50]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.40]
# |   |   |   |   |   |   |   |--- feature_4 >  0.52
# |   |   |   |   |   |   |   |   |--- value: [21.70]
# |   |   |   |   |   |--- feature_6 >  88.55
# |   |   |   |   |   |   |--- feature_5 <= 5.91
# |   |   |   |   |   |   |   |--- feature_6 <= 98.35
# |   |   |   |   |   |   |   |   |--- feature_8 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- value: [19.30]
# |   |   |   |   |   |   |   |   |--- feature_8 >  4.50
# |   |   |   |   |   |   |   |   |   |--- value: [19.50]
# |   |   |   |   |   |   |   |--- feature_6 >  98.35
# |   |   |   |   |   |   |   |   |--- value: [20.00]
# |   |   |   |   |   |   |--- feature_5 >  5.91
# |   |   |   |   |   |   |   |--- feature_7 <= 2.80
# |   |   |   |   |   |   |   |   |--- value: [19.40]
# |   |   |   |   |   |   |   |--- feature_7 >  2.80
# |   |   |   |   |   |   |   |   |--- value: [21.70]
# |   |   |   |   |--- feature_7 >  5.57
# |   |   |   |   |   |--- feature_0 <= 0.16
# |   |   |   |   |   |   |--- feature_4 <= 0.48
# |   |   |   |   |   |   |   |--- feature_10 <= 18.55
# |   |   |   |   |   |   |   |   |--- value: [20.30]
# |   |   |   |   |   |   |   |--- feature_10 >  18.55
# |   |   |   |   |   |   |   |   |--- value: [18.90]
# |   |   |   |   |   |   |--- feature_4 >  0.48
# |   |   |   |   |   |   |   |--- value: [27.10]
# |   |   |   |   |   |--- feature_0 >  0.16
# |   |   |   |   |   |   |--- feature_6 <= 89.65
# |   |   |   |   |   |   |   |--- feature_7 <= 5.89
# |   |   |   |   |   |   |   |   |--- value: [16.60]
# |   |   |   |   |   |   |   |--- feature_7 >  5.89
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.60
# |   |   |   |   |   |   |   |   |   |--- value: [19.40]
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.60
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 6.87
# |   |   |   |   |   |   |   |   |   |   |--- value: [18.50]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  6.87
# |   |   |   |   |   |   |   |   |   |   |--- value: [18.90]
# |   |   |   |   |   |   |--- feature_6 >  89.65
# |   |   |   |   |   |   |   |--- feature_0 <= 0.22
# |   |   |   |   |   |   |   |   |--- feature_7 <= 6.45
# |   |   |   |   |   |   |   |   |   |--- value: [16.50]
# |   |   |   |   |   |   |   |   |--- feature_7 >  6.45
# |   |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |   |--- feature_0 >  0.22
# |   |   |   |   |   |   |   |   |--- feature_10 <= 16.55
# |   |   |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |   |   |   |   |--- feature_10 >  16.55
# |   |   |   |   |   |   |   |   |   |--- value: [14.40]
# |   |   |   |--- feature_4 >  0.53
# |   |   |   |   |--- feature_12 <= 18.89
# |   |   |   |   |   |--- feature_6 <= 85.20
# |   |   |   |   |   |   |--- feature_12 <= 15.24
# |   |   |   |   |   |   |   |--- feature_9 <= 534.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 82.15
# |   |   |   |   |   |   |   |   |   |--- value: [17.50]
# |   |   |   |   |   |   |   |   |--- feature_6 >  82.15
# |   |   |   |   |   |   |   |   |   |--- value: [15.60]
# |   |   |   |   |   |   |   |--- feature_9 >  534.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 82.10
# |   |   |   |   |   |   |   |   |   |--- value: [19.10]
# |   |   |   |   |   |   |   |   |--- feature_6 >  82.10
# |   |   |   |   |   |   |   |   |   |--- value: [20.00]
# |   |   |   |   |   |   |--- feature_12 >  15.24
# |   |   |   |   |   |   |   |--- feature_7 <= 2.84
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.57
# |   |   |   |   |   |   |   |   |   |--- value: [20.40]
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.57
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2.74
# |   |   |   |   |   |   |   |   |   |   |--- value: [23.10]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  2.74
# |   |   |   |   |   |   |   |   |   |   |--- value: [23.20]
# |   |   |   |   |   |   |   |--- feature_7 >  2.84
# |   |   |   |   |   |   |   |   |--- feature_12 <= 17.74
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.62
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2.30
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  2.30
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.90]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |   |   |   |--- feature_12 >  17.74
# |   |   |   |   |   |   |   |   |   |--- value: [17.80]
# |   |   |   |   |   |--- feature_6 >  85.20
# |   |   |   |   |   |   |--- feature_9 <= 291.50
# |   |   |   |   |   |   |   |--- feature_5 <= 5.92
# |   |   |   |   |   |   |   |   |--- value: [18.80]
# |   |   |   |   |   |   |   |--- feature_5 >  5.92
# |   |   |   |   |   |   |   |   |--- feature_12 <= 17.93
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.97
# |   |   |   |   |   |   |   |   |   |   |--- value: [21.50]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.97
# |   |   |   |   |   |   |   |   |   |   |--- value: [21.40]
# |   |   |   |   |   |   |   |   |--- feature_12 >  17.93
# |   |   |   |   |   |   |   |   |   |--- value: [20.50]
# |   |   |   |   |   |   |--- feature_9 >  291.50
# |   |   |   |   |   |   |   |--- feature_12 <= 17.10
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.67
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.63
# |   |   |   |   |   |   |   |   |   |   |--- value: [15.60]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.63
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 89.85
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  89.85
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.10]
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.67
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 88.05
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.30]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  88.05
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_12 >  17.10
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.80
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 394.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.20]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  394.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [17.80]
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.80
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 18.52
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 18.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  18.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  18.52
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 18.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [16.70]
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  18.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.20]
# |   |   |   |   |--- feature_12 >  18.89
# |   |   |   |   |   |--- feature_9 <= 688.50
# |   |   |   |   |   |   |--- feature_6 <= 77.45
# |   |   |   |   |   |   |   |--- value: [19.70]
# |   |   |   |   |   |   |--- feature_6 >  77.45
# |   |   |   |   |   |   |   |--- feature_8 <= 3.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 364.80
# |   |   |   |   |   |   |   |   |   |--- value: [15.70]
# |   |   |   |   |   |   |   |   |--- feature_11 >  364.80
# |   |   |   |   |   |   |   |   |   |--- value: [17.30]
# |   |   |   |   |   |   |   |--- feature_8 >  3.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 95.85
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.56
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 372.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  372.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.56
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 25.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  25.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.20]
# |   |   |   |   |   |   |   |   |--- feature_6 >  95.85
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 99.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  99.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 3.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  3.71
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.60]
# |   |   |   |   |   |--- feature_9 >  688.50
# |   |   |   |   |   |   |--- feature_7 <= 1.79
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |--- feature_7 >  1.79
# |   |   |   |   |   |   |   |--- value: [8.10]
# |   |   |--- feature_0 >  6.99
# |   |   |   |--- feature_4 <= 0.61
# |   |   |   |   |--- feature_5 <= 6.84
# |   |   |   |   |   |--- feature_0 <= 12.66
# |   |   |   |   |   |   |--- feature_11 <= 52.99
# |   |   |   |   |   |   |   |--- feature_11 <= 14.15
# |   |   |   |   |   |   |   |   |--- value: [11.70]
# |   |   |   |   |   |   |   |--- feature_11 >  14.15
# |   |   |   |   |   |   |   |   |--- value: [10.20]
# |   |   |   |   |   |   |--- feature_11 >  52.99
# |   |   |   |   |   |   |   |--- feature_12 <= 23.05
# |   |   |   |   |   |   |   |   |--- feature_6 <= 90.20
# |   |   |   |   |   |   |   |   |   |--- value: [14.50]
# |   |   |   |   |   |   |   |   |--- feature_6 >  90.20
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 216.95
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.10]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  216.95
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.80]
# |   |   |   |   |   |   |   |--- feature_12 >  23.05
# |   |   |   |   |   |   |   |   |--- value: [17.20]
# |   |   |   |   |   |--- feature_0 >  12.66
# |   |   |   |   |   |   |--- feature_7 <= 2.21
# |   |   |   |   |   |   |   |--- feature_0 <= 23.73
# |   |   |   |   |   |   |   |   |--- feature_11 <= 31.92
# |   |   |   |   |   |   |   |   |   |--- value: [17.90]
# |   |   |   |   |   |   |   |   |--- feature_11 >  31.92
# |   |   |   |   |   |   |   |   |   |--- value: [17.20]
# |   |   |   |   |   |   |   |--- feature_0 >  23.73
# |   |   |   |   |   |   |   |   |--- value: [16.30]
# |   |   |   |   |   |   |--- feature_7 >  2.21
# |   |   |   |   |   |   |   |--- feature_5 <= 5.82
# |   |   |   |   |   |   |   |   |--- value: [20.10]
# |   |   |   |   |   |   |   |--- feature_5 >  5.82
# |   |   |   |   |   |   |   |   |--- value: [19.10]
# |   |   |   |   |--- feature_5 >  6.84
# |   |   |   |   |   |--- value: [27.50]
# |   |   |   |--- feature_4 >  0.61
# |   |   |   |   |--- feature_12 <= 19.65
# |   |   |   |   |   |--- feature_0 <= 12.22
# |   |   |   |   |   |   |--- feature_4 <= 0.75
# |   |   |   |   |   |   |   |--- feature_12 <= 19.41
# |   |   |   |   |   |   |   |   |--- feature_6 <= 99.40
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.73
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.73
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.60]
# |   |   |   |   |   |   |   |   |--- feature_6 >  99.40
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 10.53
# |   |   |   |   |   |   |   |   |   |   |--- value: [15.40]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  10.53
# |   |   |   |   |   |   |   |   |   |   |--- value: [16.70]
# |   |   |   |   |   |   |   |--- feature_12 >  19.41
# |   |   |   |   |   |   |   |   |--- value: [17.10]
# |   |   |   |   |   |   |--- feature_4 >  0.75
# |   |   |   |   |   |   |   |--- value: [17.80]
# |   |   |   |   |   |--- feature_0 >  12.22
# |   |   |   |   |   |   |--- feature_11 <= 64.06
# |   |   |   |   |   |   |   |--- feature_5 <= 6.33
# |   |   |   |   |   |   |   |   |--- value: [10.90]
# |   |   |   |   |   |   |   |--- feature_5 >  6.33
# |   |   |   |   |   |   |   |   |--- value: [9.60]
# |   |   |   |   |   |   |--- feature_11 >  64.06
# |   |   |   |   |   |   |   |--- feature_0 <= 13.64
# |   |   |   |   |   |   |   |   |--- value: [12.70]
# |   |   |   |   |   |   |   |--- feature_0 >  13.64
# |   |   |   |   |   |   |   |   |--- value: [11.70]
# |   |   |   |   |--- feature_12 >  19.65
# |   |   |   |   |   |--- feature_4 <= 0.68
# |   |   |   |   |   |   |--- feature_12 <= 22.51
# |   |   |   |   |   |   |   |--- feature_0 <= 12.85
# |   |   |   |   |   |   |   |   |--- value: [13.30]
# |   |   |   |   |   |   |   |--- feature_0 >  12.85
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.45
# |   |   |   |   |   |   |   |   |   |--- value: [10.20]
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.45
# |   |   |   |   |   |   |   |   |   |--- value: [10.90]
# |   |   |   |   |   |   |--- feature_12 >  22.51
# |   |   |   |   |   |   |   |--- feature_4 <= 0.66
# |   |   |   |   |   |   |   |   |--- feature_12 <= 23.32
# |   |   |   |   |   |   |   |   |   |--- value: [13.40]
# |   |   |   |   |   |   |   |   |--- feature_12 >  23.32
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.64
# |   |   |   |   |   |   |   |   |   |   |--- value: [11.90]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.64
# |   |   |   |   |   |   |   |   |   |   |--- value: [12.00]
# |   |   |   |   |   |   |   |--- feature_4 >  0.66
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.37
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 96.65
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.90]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  96.65
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.80]
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.37
# |   |   |   |   |   |   |   |   |   |--- value: [13.10]
# |   |   |   |   |   |--- feature_4 >  0.68
# |   |   |   |   |   |   |--- feature_0 <= 13.24
# |   |   |   |   |   |   |   |--- feature_12 <= 25.74
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.73
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 99.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6.60
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.40]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  99.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.56
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [12.30]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.73
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 23.53
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 94.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [12.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  94.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.40]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  23.53
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 95.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  95.70
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [10.80]
# |   |   |   |   |   |   |   |--- feature_12 >  25.74
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.69
# |   |   |   |   |   |   |   |   |   |--- value: [7.50]
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.69
# |   |   |   |   |   |   |   |   |   |--- value: [6.30]
# |   |   |   |   |   |   |--- feature_0 >  13.24
# |   |   |   |   |   |   |   |--- feature_7 <= 1.59
# |   |   |   |   |   |   |   |   |--- feature_5 <= 4.83
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 95.60
# |   |   |   |   |   |   |   |   |   |   |--- value: [8.80]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  95.60
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.50]
# |   |   |   |   |   |   |   |   |--- feature_5 >  4.83
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 23.82
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 93.80
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [7.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  93.80
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [7.20]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  23.82
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 5.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  5.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.60]
# |   |   |   |   |   |   |   |--- feature_7 >  1.59
# |   |   |   |   |   |   |   |   |--- feature_11 <= 107.81
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 21.85
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.30]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  21.85
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 15.88
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  15.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_11 >  107.81
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 20.94
# |   |   |   |   |   |   |   |   |   |   |--- value: [8.30]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  20.94
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 87.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  87.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |--- feature_5 >  6.94
# |   |--- feature_5 <= 7.44
# |   |   |--- feature_4 <= 0.66
# |   |   |   |--- feature_7 <= 1.89
# |   |   |   |   |--- feature_5 <= 6.98
# |   |   |   |   |   |--- value: [41.30]
# |   |   |   |   |--- feature_5 >  6.98
# |   |   |   |   |   |--- value: [50.00]
# |   |   |   |--- feature_7 >  1.89
# |   |   |   |   |--- feature_4 <= 0.49
# |   |   |   |   |   |--- feature_6 <= 11.95
# |   |   |   |   |   |   |--- feature_2 <= 4.05
# |   |   |   |   |   |   |   |--- value: [29.00]
# |   |   |   |   |   |   |--- feature_2 >  4.05
# |   |   |   |   |   |   |   |--- value: [29.60]
# |   |   |   |   |   |--- feature_6 >  11.95
# |   |   |   |   |   |   |--- feature_12 <= 5.44
# |   |   |   |   |   |   |   |--- feature_0 <= 0.05
# |   |   |   |   |   |   |   |   |--- feature_12 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 2.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 7.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  7.48
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.90]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  2.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [34.70]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [34.90]
# |   |   |   |   |   |   |   |   |--- feature_12 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [34.90]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 394.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [35.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  394.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [35.40]
# |   |   |   |   |   |   |   |--- feature_0 >  0.05
# |   |   |   |   |   |   |   |   |--- feature_8 <= 6.00
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 5.36
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 5.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  5.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  5.36
# |   |   |   |   |   |   |   |   |   |   |--- value: [34.90]
# |   |   |   |   |   |   |   |   |--- feature_8 >  6.00
# |   |   |   |   |   |   |   |   |   |--- value: [33.10]
# |   |   |   |   |   |   |--- feature_12 >  5.44
# |   |   |   |   |   |   |   |--- feature_6 <= 37.45
# |   |   |   |   |   |   |   |   |--- feature_1 <= 85.00
# |   |   |   |   |   |   |   |   |   |--- value: [30.30]
# |   |   |   |   |   |   |   |   |--- feature_1 >  85.00
# |   |   |   |   |   |   |   |   |   |--- value: [32.20]
# |   |   |   |   |   |   |   |--- feature_6 >  37.45
# |   |   |   |   |   |   |   |   |--- feature_6 <= 45.05
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 7.26
# |   |   |   |   |   |   |   |   |   |   |--- value: [36.10]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  7.26
# |   |   |   |   |   |   |   |   |   |   |--- value: [34.60]
# |   |   |   |   |   |   |   |   |--- feature_6 >  45.05
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.70]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 3.30
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  3.30
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.20]
# |   |   |   |   |--- feature_4 >  0.49
# |   |   |   |   |   |--- feature_5 <= 7.12
# |   |   |   |   |   |   |--- feature_4 <= 0.59
# |   |   |   |   |   |   |   |--- feature_0 <= 0.05
# |   |   |   |   |   |   |   |   |--- value: [28.70]
# |   |   |   |   |   |   |   |--- feature_0 >  0.05
# |   |   |   |   |   |   |   |   |--- feature_5 <= 6.96
# |   |   |   |   |   |   |   |   |   |--- value: [26.70]
# |   |   |   |   |   |   |   |   |--- feature_5 >  6.96
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 81.65
# |   |   |   |   |   |   |   |   |   |   |--- value: [25.00]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  81.65
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 271.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.60]
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  271.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.90]
# |   |   |   |   |   |   |--- feature_4 >  0.59
# |   |   |   |   |   |   |   |--- feature_7 <= 2.33
# |   |   |   |   |   |   |   |   |--- value: [30.70]
# |   |   |   |   |   |   |   |--- feature_7 >  2.33
# |   |   |   |   |   |   |   |   |--- value: [29.80]
# |   |   |   |   |   |--- feature_5 >  7.12
# |   |   |   |   |   |   |--- feature_7 <= 2.00
# |   |   |   |   |   |   |   |--- feature_6 <= 95.80
# |   |   |   |   |   |   |   |   |--- value: [36.50]
# |   |   |   |   |   |   |   |--- feature_6 >  95.80
# |   |   |   |   |   |   |   |   |--- value: [36.00]
# |   |   |   |   |   |   |--- feature_7 >  2.00
# |   |   |   |   |   |   |   |--- feature_5 <= 7.27
# |   |   |   |   |   |   |   |   |--- feature_1 <= 10.00
# |   |   |   |   |   |   |   |   |   |--- value: [31.60]
# |   |   |   |   |   |   |   |   |--- feature_1 >  10.00
# |   |   |   |   |   |   |   |   |   |--- value: [33.80]
# |   |   |   |   |   |   |   |--- feature_5 >  7.27
# |   |   |   |   |   |   |   |   |--- feature_5 <= 7.34
# |   |   |   |   |   |   |   |   |   |--- value: [31.00]
# |   |   |   |   |   |   |   |   |--- feature_5 >  7.34
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.51
# |   |   |   |   |   |   |   |   |   |   |--- value: [31.70]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.51
# |   |   |   |   |   |   |   |   |   |   |--- value: [31.50]
# |   |   |--- feature_4 >  0.66
# |   |   |   |--- feature_5 <= 7.14
# |   |   |   |   |--- value: [10.40]
# |   |   |   |--- feature_5 >  7.14
# |   |   |   |   |--- feature_11 <= 386.38
# |   |   |   |   |   |--- value: [17.80]
# |   |   |   |   |--- feature_11 >  386.38
# |   |   |   |   |   |--- value: [15.00]
# |   |--- feature_5 >  7.44
# |   |   |--- feature_10 <= 19.65
# |   |   |   |--- feature_10 <= 14.80
# |   |   |   |   |--- feature_5 <= 7.71
# |   |   |   |   |   |--- feature_0 <= 1.00
# |   |   |   |   |   |   |--- feature_2 <= 3.00
# |   |   |   |   |   |   |   |--- value: [42.30]
# |   |   |   |   |   |   |--- feature_2 >  3.00
# |   |   |   |   |   |   |   |--- feature_4 <= 0.61
# |   |   |   |   |   |   |   |   |--- value: [43.50]
# |   |   |   |   |   |   |   |--- feature_4 >  0.61
# |   |   |   |   |   |   |   |   |--- value: [43.10]
# |   |   |   |   |   |--- feature_0 >  1.00
# |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |--- feature_5 >  7.71
# |   |   |   |   |   |--- feature_12 <= 3.75
# |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |   |--- feature_12 >  3.75
# |   |   |   |   |   |   |--- feature_0 <= 0.55
# |   |   |   |   |   |   |   |--- feature_6 <= 62.35
# |   |   |   |   |   |   |   |   |--- value: [48.50]
# |   |   |   |   |   |   |   |--- feature_6 >  62.35
# |   |   |   |   |   |   |   |   |--- value: [48.80]
# |   |   |   |   |   |   |--- feature_0 >  0.55
# |   |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |--- feature_10 >  14.80
# |   |   |   |   |--- feature_11 <= 385.48
# |   |   |   |   |   |--- feature_0 <= 0.32
# |   |   |   |   |   |   |--- feature_11 <= 381.28
# |   |   |   |   |   |   |   |--- feature_4 <= 0.47
# |   |   |   |   |   |   |   |   |--- value: [46.00]
# |   |   |   |   |   |   |   |--- feature_4 >  0.47
# |   |   |   |   |   |   |   |   |--- value: [46.70]
# |   |   |   |   |   |   |--- feature_11 >  381.28
# |   |   |   |   |   |   |   |--- value: [44.80]
# |   |   |   |   |   |--- feature_0 >  0.32
# |   |   |   |   |   |   |--- feature_7 <= 3.27
# |   |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |   |   |--- feature_7 >  3.27
# |   |   |   |   |   |   |   |--- value: [48.30]
# |   |   |   |   |--- feature_11 >  385.48
# |   |   |   |   |   |--- feature_0 <= 0.06
# |   |   |   |   |   |   |--- feature_5 <= 7.83
# |   |   |   |   |   |   |   |--- feature_7 <= 5.52
# |   |   |   |   |   |   |   |   |--- value: [45.40]
# |   |   |   |   |   |   |   |--- feature_7 >  5.52
# |   |   |   |   |   |   |   |   |--- value: [44.00]
# |   |   |   |   |   |   |--- feature_5 >  7.83
# |   |   |   |   |   |   |   |--- value: [50.00]
# |   |   |   |   |   |--- feature_0 >  0.06
# |   |   |   |   |   |   |--- feature_6 <= 44.35
# |   |   |   |   |   |   |   |--- feature_9 <= 303.00
# |   |   |   |   |   |   |   |   |--- value: [43.80]
# |   |   |   |   |   |   |   |--- feature_9 >  303.00
# |   |   |   |   |   |   |   |   |--- value: [42.80]
# |   |   |   |   |   |   |--- feature_6 >  44.35
# |   |   |   |   |   |   |   |--- feature_6 <= 62.55
# |   |   |   |   |   |   |   |   |--- value: [35.20]
# |   |   |   |   |   |   |   |--- feature_6 >  62.55
# |   |   |   |   |   |   |   |   |--- feature_5 <= 8.20
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 396.23
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [39.80]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  396.23
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [38.70]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [37.60]
# |   |   |   |   |   |   |   |   |--- feature_5 >  8.20
# |   |   |   |   |   |   |   |   |   |--- value: [41.70]
# |   |   |--- feature_10 >  19.65
# |   |   |   |--- value: [21.90]

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model)
# Out:
# [Text(0.6834018682342728, 0.975, 'X[5] <= 6.941\nsquared_error = 84.42\nsamples = 506\nvalue = 22.533'),
#  Text(0.4277281062164449, 0.925, 'X[12] <= 14.4\nsquared_error = 40.273\nsamples = 430\nvalue = 19.934'),
#  Text(0.1916526701826564, 0.875, 'X[7] <= 1.385\nsquared_error = 26.009\nsamples = 255\nvalue = 23.35'),
#  Text(0.1090421845821662, 0.825, 'X[12] <= 10.83\nsquared_error = 78.146\nsamples = 5\nvalue = 45.58'),
#  Text(0.10717477095004668, 0.775, 'squared_error = 0.0\nsamples = 4\nvalue = 50.0'),
#  Text(0.11090959821428571, 0.775, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.2742631557831466, 0.825, 'X[5] <= 6.543\nsquared_error = 14.885\nsamples = 250\nvalue = 22.905'),
#  Text(0.11464442547852474, 0.775, 'X[12] <= 7.57\nsquared_error = 8.39\nsamples = 195\nvalue = 21.63'),
#  Text(0.04105392156862745, 0.725, 'X[9] <= 222.5\nsquared_error = 3.015\nsamples = 43\nvalue = 23.97'),
#  Text(0.039186507936507936, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.042921335200746966, 0.675, 'X[2] <= 5.48\nsquared_error = 2.541\nsamples = 42\nvalue = 23.857'),
#  Text(0.02964519140989729, 0.625, 'X[10] <= 19.95\nsquared_error = 1.328\nsamples = 19\nvalue = 23.011'),
#  Text(0.018207282913165267, 0.575, 'X[11] <= 393.33\nsquared_error = 0.72\nsamples = 16\nvalue = 23.356'),
#  Text(0.007469654528478058, 0.525, 'X[2] <= 3.895\nsquared_error = 0.337\nsamples = 8\nvalue = 22.962'),
#  Text(0.003734827264239029, 0.475, 'X[8] <= 2.5\nsquared_error = 0.096\nsamples = 3\nvalue = 22.333'),
#  Text(0.0018674136321195146, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 21.9'),
#  Text(0.0056022408963585435, 0.425, 'X[4] <= 0.43\nsquared_error = 0.002\nsamples = 2\nvalue = 22.55'),
#  Text(0.003734827264239029, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.007469654528478058, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.011204481792717087, 0.475, 'X[6] <= 23.1\nsquared_error = 0.102\nsamples = 5\nvalue = 23.34'),
#  Text(0.009337068160597572, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 23.7'),
#  Text(0.013071895424836602, 0.425, 'X[7] <= 6.608\nsquared_error = 0.027\nsamples = 3\nvalue = 23.1'),
#  Text(0.011204481792717087, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.014939309056956116, 0.375, 'X[1] <= 55.0\nsquared_error = 0.01\nsamples = 2\nvalue = 23.2'),
#  Text(0.013071895424836602, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.01680672268907563, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.028944911297852476, 0.525, 'X[10] <= 19.35\nsquared_error = 0.792\nsamples = 8\nvalue = 23.75'),
#  Text(0.02427637721755369, 0.475, 'X[6] <= 31.75\nsquared_error = 0.376\nsamples = 6\nvalue = 24.15'),
#  Text(0.02054154995331466, 0.425, 'X[4] <= 0.402\nsquared_error = 0.022\nsamples = 2\nvalue = 23.35'),
#  Text(0.018674136321195144, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 23.5'),
#  Text(0.022408963585434174, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.028011204481792718, 0.425, 'X[11] <= 394.685\nsquared_error = 0.073\nsamples = 4\nvalue = 24.55'),
#  Text(0.026143790849673203, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.1'),
#  Text(0.029878618113912233, 0.375, 'X[0] <= 0.045\nsquared_error = 0.007\nsamples = 3\nvalue = 24.7'),
#  Text(0.028011204481792718, 0.325, 'X[9] <= 297.0\nsquared_error = 0.003\nsamples = 2\nvalue = 24.75'),
#  Text(0.026143790849673203, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.029878618113912233, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.031746031746031744, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.03361344537815126, 0.475, 'X[0] <= 0.086\nsquared_error = 0.123\nsamples = 2\nvalue = 22.55'),
#  Text(0.031746031746031744, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.035480859010270774, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.04108309990662932, 0.575, 'X[5] <= 6.313\nsquared_error = 0.536\nsamples = 3\nvalue = 21.167'),
#  Text(0.0392156862745098, 0.525, 'X[0] <= 0.072\nsquared_error = 0.003\nsamples = 2\nvalue = 20.65'),
#  Text(0.03734827264239029, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 20.7'),
#  Text(0.04108309990662932, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.04295051353874883, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.05619747899159664, 0.625, 'X[1] <= 34.0\nsquared_error = 2.462\nsamples = 23\nvalue = 24.557'),
#  Text(0.054330065359477125, 0.575, 'X[11] <= 359.505\nsquared_error = 1.592\nsamples = 22\nvalue = 24.35'),
#  Text(0.04668534080298786, 0.525, 'X[6] <= 96.3\nsquared_error = 1.976\nsamples = 3\nvalue = 26.267'),
#  Text(0.04481792717086835, 0.475, 'X[4] <= 0.662\nsquared_error = 0.062\nsamples = 2\nvalue = 27.25'),
#  Text(0.04295051353874883, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.04668534080298786, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 27.5'),
#  Text(0.04855275443510738, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.06197478991596639, 0.525, 'X[5] <= 6.146\nsquared_error = 0.86\nsamples = 19\nvalue = 24.047'),
#  Text(0.05228758169934641, 0.475, 'X[10] <= 18.8\nsquared_error = 0.176\nsamples = 3\nvalue = 22.667'),
#  Text(0.05042016806722689, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 22.1'),
#  Text(0.05415499533146592, 0.425, 'X[4] <= 0.475\nsquared_error = 0.023\nsamples = 2\nvalue = 22.95'),
#  Text(0.05228758169934641, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.056022408963585436, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.07166199813258636, 0.475, 'X[9] <= 278.5\nsquared_error = 0.564\nsamples = 16\nvalue = 24.306'),
#  Text(0.06162464985994398, 0.425, 'X[6] <= 6.55\nsquared_error = 0.042\nsamples = 5\nvalue = 25.04'),
#  Text(0.059757236227824466, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.06349206349206349, 0.375, 'X[9] <= 238.0\nsquared_error = 0.017\nsamples = 4\nvalue = 25.125'),
#  Text(0.06162464985994398, 0.325, 'X[9] <= 228.0\nsquared_error = 0.003\nsamples = 2\nvalue = 25.25'),
#  Text(0.059757236227824466, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 25.2'),
#  Text(0.06349206349206349, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.06535947712418301, 0.325, 'squared_error = 0.0\nsamples = 2\nvalue = 25.0'),
#  Text(0.08169934640522876, 0.425, 'X[12] <= 6.135\nsquared_error = 0.446\nsamples = 11\nvalue = 23.973'),
#  Text(0.07282913165266107, 0.375, 'X[0] <= 0.203\nsquared_error = 0.05\nsamples = 4\nvalue = 24.7'),
#  Text(0.06909430438842204, 0.325, 'X[10] <= 19.35\nsquared_error = 0.01\nsamples = 2\nvalue = 24.5'),
#  Text(0.06722689075630252, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.07096171802054155, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.0765639589169001, 0.325, 'X[6] <= 24.5\nsquared_error = 0.01\nsamples = 2\nvalue = 24.9'),
#  Text(0.07469654528478058, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.0784313725490196, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.09056956115779645, 0.375, 'X[0] <= 0.175\nsquared_error = 0.197\nsamples = 7\nvalue = 23.557'),
#  Text(0.08403361344537816, 0.325, 'X[9] <= 296.0\nsquared_error = 0.029\nsamples = 3\nvalue = 24.033'),
#  Text(0.08216619981325864, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.08590102707749767, 0.275, 'X[6] <= 6.3\nsquared_error = 0.002\nsamples = 2\nvalue = 24.15'),
#  Text(0.08403361344537816, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 24.1'),
#  Text(0.08776844070961717, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 24.2'),
#  Text(0.09710550887021475, 0.325, 'X[10] <= 19.4\nsquared_error = 0.025\nsamples = 4\nvalue = 23.2'),
#  Text(0.09337068160597572, 0.275, 'X[6] <= 53.1\nsquared_error = 0.002\nsamples = 2\nvalue = 23.35'),
#  Text(0.0915032679738562, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 23.4'),
#  Text(0.09523809523809523, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.10084033613445378, 0.275, 'X[6] <= 41.6\nsquared_error = 0.002\nsamples = 2\nvalue = 23.05'),
#  Text(0.09897292250233426, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.10270774976657329, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.058064892623716155, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 29.1'),
#  Text(0.18823492938842204, 0.725, 'X[9] <= 208.0\nsquared_error = 7.924\nsamples = 152\nvalue = 20.968'),
#  Text(0.1119281045751634, 0.675, 'X[6] <= 69.25\nsquared_error = 32.32\nsamples = 5\nvalue = 26.9'),
#  Text(0.10819327731092437, 0.625, 'X[5] <= 6.148\nsquared_error = 10.89\nsamples = 2\nvalue = 32.9'),
#  Text(0.10632586367880485, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 36.2'),
#  Text(0.11006069094304388, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.11566293183940243, 0.625, 'X[10] <= 18.45\nsquared_error = 6.607\nsamples = 3\nvalue = 22.9'),
#  Text(0.11379551820728291, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 26.4'),
#  Text(0.11753034547152194, 0.575, 'X[6] <= 76.9\nsquared_error = 0.723\nsamples = 2\nvalue = 21.15'),
#  Text(0.11566293183940243, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.11939775910364146, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.2645417542016807, 0.675, 'X[5] <= 6.078\nsquared_error = 5.856\nsamples = 147\nvalue = 20.766'),
#  Text(0.20432860644257703, 0.625, 'X[6] <= 69.1\nsquared_error = 5.537\nsamples = 79\nvalue = 19.997'),
#  Text(0.153171685340803, 0.575, 'X[7] <= 4.464\nsquared_error = 3.664\nsamples = 55\nvalue = 20.513'),
#  Text(0.12313258636788049, 0.525, 'X[5] <= 5.214\nsquared_error = 3.847\nsamples = 23\nvalue = 21.465'),
#  Text(0.12126517273576097, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.125, 0.475, 'X[10] <= 17.6\nsquared_error = 2.654\nsamples = 22\nvalue = 21.709'),
#  Text(0.10830999066293184, 0.425, 'X[4] <= 0.507\nsquared_error = 0.346\nsamples = 5\nvalue = 23.24'),
#  Text(0.10644257703081232, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.11017740429505135, 0.375, 'X[0] <= 0.077\nsquared_error = 0.082\nsamples = 4\nvalue = 22.975'),
#  Text(0.10644257703081232, 0.325, 'X[5] <= 5.954\nsquared_error = 0.003\nsamples = 2\nvalue = 23.25'),
#  Text(0.10457516339869281, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.10830999066293184, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.11391223155929038, 0.325, 'X[9] <= 280.0\nsquared_error = 0.01\nsamples = 2\nvalue = 22.7'),
#  Text(0.11204481792717087, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.1157796451914099, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.14169000933706816, 0.425, 'X[6] <= 46.65\nsquared_error = 2.441\nsamples = 17\nvalue = 21.259'),
#  Text(0.13071895424836602, 0.375, 'X[5] <= 5.881\nsquared_error = 2.343\nsamples = 9\nvalue = 22.111'),
#  Text(0.12324929971988796, 0.325, 'X[11] <= 379.69\nsquared_error = 0.286\nsamples = 5\nvalue = 20.94'),
#  Text(0.11951447245564893, 0.275, 'X[2] <= 13.12\nsquared_error = 0.04\nsamples = 2\nvalue = 20.4'),
#  Text(0.11764705882352941, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.2'),
#  Text(0.12138188608776844, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.12698412698412698, 0.275, 'X[10] <= 19.7\nsquared_error = 0.127\nsamples = 3\nvalue = 21.3'),
#  Text(0.12511671335200747, 0.225, 'X[4] <= 0.481\nsquared_error = 0.003\nsamples = 2\nvalue = 21.05'),
#  Text(0.12324929971988796, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 21.1'),
#  Text(0.12698412698412698, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.12885154061624648, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.13818860877684408, 0.325, 'X[7] <= 3.896\nsquared_error = 1.057\nsamples = 4\nvalue = 23.575'),
#  Text(0.13445378151260504, 0.275, 'X[4] <= 0.542\nsquared_error = 0.01\nsamples = 2\nvalue = 24.6'),
#  Text(0.13258636788048553, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.13632119514472454, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.1419234360410831, 0.275, 'X[2] <= 7.54\nsquared_error = 0.002\nsamples = 2\nvalue = 22.55'),
#  Text(0.1400560224089636, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.1437908496732026, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.15266106442577032, 0.375, 'X[7] <= 2.584\nsquared_error = 0.815\nsamples = 8\nvalue = 20.3'),
#  Text(0.14752567693744165, 0.325, 'X[5] <= 5.863\nsquared_error = 0.09\nsamples = 2\nvalue = 21.5'),
#  Text(0.14565826330532214, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.14939309056956115, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.15779645191409897, 0.325, 'X[6] <= 63.35\nsquared_error = 0.417\nsamples = 6\nvalue = 19.9'),
#  Text(0.1531279178338002, 0.275, 'X[11] <= 382.89\nsquared_error = 0.125\nsamples = 4\nvalue = 20.3'),
#  Text(0.14939309056956115, 0.225, 'X[0] <= 1.631\nsquared_error = 0.002\nsamples = 2\nvalue = 19.95'),
#  Text(0.14752567693744165, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.15126050420168066, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.9'),
#  Text(0.1568627450980392, 0.225, 'X[6] <= 57.35\nsquared_error = 0.003\nsamples = 2\nvalue = 20.65'),
#  Text(0.1549953314659197, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.15873015873015872, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.7'),
#  Text(0.16246498599439776, 0.275, 'X[7] <= 3.06\nsquared_error = 0.04\nsamples = 2\nvalue = 19.1'),
#  Text(0.16059757236227826, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.16433239962651727, 0.225, 'squared_error = -0.0\nsamples = 1\nvalue = 18.9'),
#  Text(0.18321078431372548, 0.525, 'X[5] <= 5.763\nsquared_error = 2.411\nsamples = 32\nvalue = 19.828'),
#  Text(0.16806722689075632, 0.475, 'X[0] <= 0.142\nsquared_error = 0.658\nsamples = 5\nvalue = 18.14'),
#  Text(0.16433239962651727, 0.425, 'X[6] <= 25.15\nsquared_error = 0.216\nsamples = 3\nvalue = 17.567'),
#  Text(0.16246498599439776, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.16619981325863678, 0.375, 'X[11] <= 395.46\nsquared_error = 0.022\nsamples = 2\nvalue = 17.25'),
#  Text(0.16433239962651727, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 17.1'),
#  Text(0.16806722689075632, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.17180205415499533, 0.425, 'X[11] <= 396.005\nsquared_error = 0.09\nsamples = 2\nvalue = 19.0'),
#  Text(0.16993464052287582, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.17366946778711484, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.19835434173669467, 0.475, 'X[2] <= 5.415\nsquared_error = 2.11\nsamples = 27\nvalue = 20.141'),
#  Text(0.1858076563958917, 0.425, 'X[6] <= 47.85\nsquared_error = 1.291\nsamples = 13\nvalue = 19.223'),
#  Text(0.17740429505135388, 0.375, 'X[0] <= 0.042\nsquared_error = 0.684\nsamples = 9\nvalue = 19.778'),
#  Text(0.17180205415499533, 0.325, 'X[6] <= 41.8\nsquared_error = 0.382\nsamples = 4\nvalue = 20.525'),
#  Text(0.16993464052287582, 0.275, 'X[0] <= 0.034\nsquared_error = 0.042\nsamples = 3\nvalue = 20.867'),
#  Text(0.16806722689075632, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.17180205415499533, 0.225, 'X[5] <= 5.957\nsquared_error = 0.01\nsamples = 2\nvalue = 21.0'),
#  Text(0.16993464052287582, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.17366946778711484, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 21.1'),
#  Text(0.17366946778711484, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 19.5'),
#  Text(0.1830065359477124, 0.325, 'X[7] <= 8.821\nsquared_error = 0.122\nsamples = 5\nvalue = 19.18'),
#  Text(0.1811391223155929, 0.275, 'X[4] <= 0.487\nsquared_error = 0.047\nsamples = 4\nvalue = 19.325'),
#  Text(0.1792717086834734, 0.225, 'X[7] <= 6.772\nsquared_error = 0.016\nsamples = 3\nvalue = 19.433'),
#  Text(0.17740429505135388, 0.175, 'X[1] <= 40.0\nsquared_error = 0.002\nsamples = 2\nvalue = 19.35'),
#  Text(0.17553688141923435, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.1792717086834734, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.1811391223155929, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.1830065359477124, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.0'),
#  Text(0.18487394957983194, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.1942110177404295, 0.375, 'X[2] <= 4.79\nsquared_error = 0.407\nsamples = 4\nvalue = 17.975'),
#  Text(0.19047619047619047, 0.325, 'X[11] <= 375.125\nsquared_error = 0.022\nsamples = 2\nvalue = 17.35'),
#  Text(0.18860877684407096, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 17.2'),
#  Text(0.19234360410831, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.19794584500466852, 0.325, 'X[11] <= 395.855\nsquared_error = 0.01\nsamples = 2\nvalue = 18.6'),
#  Text(0.19607843137254902, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.19981325863678806, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.21090102707749767, 0.425, 'X[6] <= 22.35\nsquared_error = 1.362\nsamples = 14\nvalue = 20.993'),
#  Text(0.20354808590102708, 0.375, 'X[10] <= 17.85\nsquared_error = 0.549\nsamples = 3\nvalue = 22.367'),
#  Text(0.20168067226890757, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 23.4'),
#  Text(0.20541549953314658, 0.325, 'X[11] <= 386.575\nsquared_error = 0.023\nsamples = 2\nvalue = 21.85'),
#  Text(0.20354808590102708, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.20728291316526612, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.21825396825396826, 0.375, 'X[10] <= 16.4\nsquared_error = 0.929\nsamples = 11\nvalue = 20.618'),
#  Text(0.21288515406162464, 0.325, 'X[8] <= 4.5\nsquared_error = 0.36\nsamples = 2\nvalue = 22.3'),
#  Text(0.21101774042950514, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.21475256769374415, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.22362278244631187, 0.325, 'X[1] <= 16.75\nsquared_error = 0.287\nsamples = 9\nvalue = 20.244'),
#  Text(0.2184873949579832, 0.275, 'X[7] <= 5.411\nsquared_error = 0.185\nsamples = 7\nvalue = 20.443'),
#  Text(0.2138188608776844, 0.225, 'X[5] <= 5.854\nsquared_error = 0.044\nsamples = 5\nvalue = 20.2'),
#  Text(0.21008403361344538, 0.175, 'X[6] <= 44.9\nsquared_error = 0.002\nsamples = 2\nvalue = 19.95'),
#  Text(0.20821661998132587, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.2119514472455649, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 19.9'),
#  Text(0.21755368814192344, 0.175, 'X[2] <= 10.485\nsquared_error = 0.002\nsamples = 3\nvalue = 20.367'),
#  Text(0.21568627450980393, 0.125, 'squared_error = 0.0\nsamples = 2\nvalue = 20.4'),
#  Text(0.21942110177404295, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.223155929038282, 0.225, 'X[6] <= 36.5\nsquared_error = 0.022\nsamples = 2\nvalue = 21.05'),
#  Text(0.22128851540616246, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.2250233426704015, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.22875816993464052, 0.275, 'X[12] <= 10.64\nsquared_error = 0.023\nsamples = 2\nvalue = 19.55'),
#  Text(0.226890756302521, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.23062558356676005, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.25548552754435105, 0.575, 'X[5] <= 6.029\nsquared_error = 7.826\nsamples = 24\nvalue = 18.817'),
#  Text(0.24579831932773108, 0.525, 'X[4] <= 0.601\nsquared_error = 5.256\nsamples = 22\nvalue = 19.327'),
#  Text(0.23202614379084968, 0.475, 'X[7] <= 2.623\nsquared_error = 2.162\nsamples = 12\nvalue = 18.167'),
#  Text(0.226890756302521, 0.425, 'X[7] <= 1.956\nsquared_error = 0.81\nsamples = 2\nvalue = 15.9'),
#  Text(0.2250233426704015, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.22875816993464052, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 16.8'),
#  Text(0.23716153127917833, 0.425, 'X[5] <= 5.707\nsquared_error = 1.2\nsamples = 10\nvalue = 18.62'),
#  Text(0.23249299719887956, 0.375, 'X[11] <= 384.455\nsquared_error = 0.49\nsamples = 2\nvalue = 16.9'),
#  Text(0.23062558356676005, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 17.6'),
#  Text(0.23436041083099907, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 16.2'),
#  Text(0.24183006535947713, 0.375, 'X[5] <= 5.88\nsquared_error = 0.453\nsamples = 8\nvalue = 19.05'),
#  Text(0.23809523809523808, 0.325, 'X[6] <= 72.45\nsquared_error = 0.016\nsamples = 3\nvalue = 18.333'),
#  Text(0.23622782446311857, 0.275, 'X[6] <= 70.05\nsquared_error = 0.002\nsamples = 2\nvalue = 18.25'),
#  Text(0.23436041083099907, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.23809523809523808, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.23996265172735762, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.24556489262371614, 0.325, 'X[12] <= 10.135\nsquared_error = 0.222\nsamples = 5\nvalue = 19.48'),
#  Text(0.24369747899159663, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.24743230625583568, 0.275, 'X[0] <= 0.206\nsquared_error = 0.067\nsamples = 4\nvalue = 19.275'),
#  Text(0.24369747899159663, 0.225, 'X[6] <= 82.75\nsquared_error = 0.023\nsamples = 2\nvalue = 19.05'),
#  Text(0.24183006535947713, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.24556489262371614, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 18.9'),
#  Text(0.2511671335200747, 0.225, 'X[5] <= 5.994\nsquared_error = 0.01\nsamples = 2\nvalue = 19.5'),
#  Text(0.24929971988795518, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.2530345471521942, 0.175, 'squared_error = -0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.25957049486461253, 0.475, 'X[3] <= 0.5\nsquared_error = 5.412\nsamples = 10\nvalue = 20.72'),
#  Text(0.25770308123249297, 0.425, 'X[11] <= 259.58\nsquared_error = 2.386\nsamples = 9\nvalue = 21.322'),
#  Text(0.2530345471521942, 0.375, 'X[8] <= 14.5\nsquared_error = 0.122\nsamples = 2\nvalue = 23.45'),
#  Text(0.2511671335200747, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.2549019607843137, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.2623716153127918, 0.375, 'X[6] <= 96.75\nsquared_error = 1.37\nsamples = 7\nvalue = 20.714'),
#  Text(0.2586367880485528, 0.325, 'X[7] <= 2.266\nsquared_error = 0.85\nsamples = 5\nvalue = 21.26'),
#  Text(0.2567693744164332, 0.275, 'X[7] <= 1.852\nsquared_error = 0.415\nsamples = 4\nvalue = 20.9'),
#  Text(0.2549019607843137, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.9'),
#  Text(0.2586367880485528, 0.225, 'X[9] <= 688.5\nsquared_error = 0.109\nsamples = 3\nvalue = 20.567'),
#  Text(0.2567693744164332, 0.175, 'squared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(0.2605042016806723, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.2605042016806723, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.2661064425770308, 0.325, 'X[5] <= 5.642\nsquared_error = 0.063\nsamples = 2\nvalue = 19.35'),
#  Text(0.2642390289449113, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.2679738562091503, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.26143790849673204, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 15.3'),
#  Text(0.26517273576097106, 0.525, 'X[4] <= 0.556\nsquared_error = 1.69\nsamples = 2\nvalue = 13.2'),
#  Text(0.26330532212885155, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 14.5'),
#  Text(0.26704014939309056, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.3247549019607843, 0.625, 'X[12] <= 9.98\nsquared_error = 4.744\nsamples = 68\nvalue = 21.659'),
#  Text(0.28699813258636786, 0.575, 'X[0] <= 0.046\nsquared_error = 5.482\nsamples = 24\nvalue = 22.921'),
#  Text(0.2773109243697479, 0.525, 'X[5] <= 6.497\nsquared_error = 3.299\nsamples = 9\nvalue = 20.911'),
#  Text(0.2754435107376284, 0.475, 'X[5] <= 6.23\nsquared_error = 0.975\nsamples = 8\nvalue = 21.463'),
#  Text(0.2698412698412698, 0.425, 'X[6] <= 47.6\nsquared_error = 0.127\nsamples = 3\nvalue = 20.3'),
#  Text(0.2679738562091503, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 19.8'),
#  Text(0.27170868347338933, 0.375, 'X[11] <= 395.435\nsquared_error = 0.002\nsamples = 2\nvalue = 20.55'),
#  Text(0.2698412698412698, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 20.5'),
#  Text(0.2735760971055089, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.28104575163398693, 0.425, 'X[10] <= 18.0\nsquared_error = 0.186\nsamples = 5\nvalue = 22.16'),
#  Text(0.2791783380018674, 0.375, 'X[9] <= 256.0\nsquared_error = 0.062\nsamples = 4\nvalue = 21.975'),
#  Text(0.2773109243697479, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 21.6'),
#  Text(0.28104575163398693, 0.325, 'X[0] <= 0.043\nsquared_error = 0.02\nsamples = 3\nvalue = 22.1'),
#  Text(0.2791783380018674, 0.275, 'squared_error = 0.0\nsamples = 2\nvalue = 22.0'),
#  Text(0.28291316526610644, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.28291316526610644, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.2791783380018674, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.29668534080298786, 0.525, 'X[6] <= 33.6\nsquared_error = 2.915\nsamples = 15\nvalue = 24.127'),
#  Text(0.28664799253034545, 0.475, 'X[5] <= 6.251\nsquared_error = 2.976\nsamples = 3\nvalue = 26.133'),
#  Text(0.28478057889822594, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.28851540616246496, 0.425, 'X[12] <= 9.025\nsquared_error = 0.722\nsamples = 2\nvalue = 27.25'),
#  Text(0.28664799253034545, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 26.4'),
#  Text(0.2903828197945845, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 28.1'),
#  Text(0.3067226890756303, 0.475, 'X[12] <= 9.1\nsquared_error = 1.642\nsamples = 12\nvalue = 23.625'),
#  Text(0.2987861811391223, 0.425, 'X[12] <= 7.845\nsquared_error = 1.662\nsamples = 7\nvalue = 22.971'),
#  Text(0.29411764705882354, 0.375, 'X[5] <= 6.468\nsquared_error = 0.09\nsamples = 2\nvalue = 24.7'),
#  Text(0.29225023342670403, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.29598506069094305, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.3034547152194211, 0.375, 'X[2] <= 4.27\nsquared_error = 0.618\nsamples = 5\nvalue = 22.28'),
#  Text(0.29971988795518206, 0.325, 'X[12] <= 8.925\nsquared_error = 0.25\nsamples = 2\nvalue = 23.1'),
#  Text(0.29785247432306255, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.30158730158730157, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.30718954248366015, 0.325, 'X[11] <= 394.27\nsquared_error = 0.116\nsamples = 3\nvalue = 21.733'),
#  Text(0.30532212885154064, 0.275, 'X[10] <= 18.55\nsquared_error = 0.01\nsamples = 2\nvalue = 21.5'),
#  Text(0.3034547152194211, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.6'),
#  Text(0.30718954248366015, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.30905695611577966, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.3146591970121382, 0.425, 'X[7] <= 4.362\nsquared_error = 0.178\nsamples = 5\nvalue = 24.54'),
#  Text(0.3127917833800187, 0.375, 'squared_error = 0.0\nsamples = 2\nvalue = 25.0'),
#  Text(0.3165266106442577, 0.375, 'X[12] <= 9.57\nsquared_error = 0.062\nsamples = 3\nvalue = 24.233'),
#  Text(0.3146591970121382, 0.325, 'X[0] <= 0.252\nsquared_error = 0.01\nsamples = 2\nvalue = 24.4'),
#  Text(0.3127917833800187, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.3165266106442577, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.3183940242763772, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.36251167133520074, 0.575, 'X[11] <= 197.52\nsquared_error = 2.998\nsamples = 44\nvalue = 20.97'),
#  Text(0.3510737628384687, 0.525, 'X[11] <= 84.375\nsquared_error = 1.562\nsamples = 2\nvalue = 17.35'),
#  Text(0.3492063492063492, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.35294117647058826, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.3739495798319328, 0.525, 'X[10] <= 20.55\nsquared_error = 2.412\nsamples = 42\nvalue = 21.143'),
#  Text(0.3566760037348273, 0.475, 'X[5] <= 6.318\nsquared_error = 2.003\nsamples = 32\nvalue = 21.509'),
#  Text(0.3403361344537815, 0.425, 'X[5] <= 6.246\nsquared_error = 1.539\nsamples = 23\nvalue = 21.061'),
#  Text(0.32866479925303455, 0.375, 'X[5] <= 6.09\nsquared_error = 1.24\nsamples = 17\nvalue = 21.453'),
#  Text(0.32212885154061627, 0.325, 'X[4] <= 0.5\nsquared_error = 0.81\nsamples = 2\nvalue = 23.1'),
#  Text(0.3202614379084967, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.3239962651727358, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 24.0'),
#  Text(0.3352007469654528, 0.325, 'X[0] <= 4.15\nsquared_error = 0.888\nsamples = 15\nvalue = 21.233'),
#  Text(0.3277310924369748, 0.275, 'X[9] <= 549.0\nsquared_error = 0.368\nsamples = 10\nvalue = 20.74'),
#  Text(0.3258636788048553, 0.225, 'X[4] <= 0.434\nsquared_error = 0.249\nsamples = 9\nvalue = 20.867'),
#  Text(0.3202614379084967, 0.175, 'X[10] <= 18.65\nsquared_error = 0.036\nsamples = 3\nvalue = 20.233'),
#  Text(0.3183940242763772, 0.125, 'squared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.32212885154061627, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 20.5'),
#  Text(0.3314659197012138, 0.175, 'X[6] <= 64.2\nsquared_error = 0.055\nsamples = 6\nvalue = 21.183'),
#  Text(0.3258636788048553, 0.125, 'X[12] <= 11.305\nsquared_error = 0.027\nsamples = 3\nvalue = 21.0'),
#  Text(0.3239962651727358, 0.075, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.3277310924369748, 0.075, 'X[6] <= 56.25\nsquared_error = 0.01\nsamples = 2\nvalue = 21.1'),
#  Text(0.3258636788048553, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.3295985060690943, 0.025, 'squared_error = -0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.3370681605975724, 0.125, 'X[5] <= 6.17\nsquared_error = 0.016\nsamples = 3\nvalue = 21.367'),
#  Text(0.3352007469654528, 0.075, 'X[9] <= 339.5\nsquared_error = 0.003\nsamples = 2\nvalue = 21.45'),
#  Text(0.3333333333333333, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.3370681605975724, 0.025, 'squared_error = 0.0\nsamples = 1\nvalue = 21.5'),
#  Text(0.3389355742296919, 0.075, 'squared_error = -0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.3295985060690943, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.3426704014939309, 0.275, 'X[12] <= 12.89\nsquared_error = 0.466\nsamples = 5\nvalue = 22.22'),
#  Text(0.3408029878618114, 0.225, 'X[12] <= 11.11\nsquared_error = 0.029\nsamples = 3\nvalue = 22.767'),
#  Text(0.3389355742296919, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.3426704014939309, 0.175, 'X[7] <= 2.616\nsquared_error = 0.002\nsamples = 2\nvalue = 22.65'),
#  Text(0.3408029878618114, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.3445378151260504, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.3445378151260504, 0.225, 'squared_error = -0.0\nsamples = 2\nvalue = 21.4'),
#  Text(0.3520074696545285, 0.375, 'X[7] <= 3.175\nsquared_error = 0.716\nsamples = 6\nvalue = 19.95'),
#  Text(0.34827264239028943, 0.325, 'X[0] <= 1.99\nsquared_error = 0.347\nsamples = 3\nvalue = 19.3'),
#  Text(0.3464052287581699, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.35014005602240894, 0.275, 'X[11] <= 373.775\nsquared_error = 0.04\nsamples = 2\nvalue = 19.7'),
#  Text(0.34827264239028943, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.9'),
#  Text(0.3520074696545285, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.5'),
#  Text(0.3557422969187675, 0.325, 'X[11] <= 381.14\nsquared_error = 0.24\nsamples = 3\nvalue = 20.6'),
#  Text(0.353874883286648, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.357609710550887, 0.275, 'X[0] <= 1.858\nsquared_error = 0.09\nsamples = 2\nvalue = 20.9'),
#  Text(0.3557422969187675, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.6'),
#  Text(0.35947712418300654, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.373015873015873, 0.425, 'X[0] <= 3.709\nsquared_error = 1.36\nsamples = 9\nvalue = 22.656'),
#  Text(0.3678804855275444, 0.375, 'X[5] <= 6.342\nsquared_error = 0.52\nsamples = 7\nvalue = 23.143'),
#  Text(0.36321195144724555, 0.325, 'X[10] <= 16.65\nsquared_error = 0.09\nsamples = 2\nvalue = 24.1'),
#  Text(0.36134453781512604, 0.275, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.36507936507936506, 0.275, 'squared_error = -0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.37254901960784315, 0.325, 'X[11] <= 383.06\nsquared_error = 0.178\nsamples = 5\nvalue = 22.76'),
#  Text(0.36881419234360413, 0.275, 'X[8] <= 5.5\nsquared_error = 0.002\nsamples = 2\nvalue = 22.25'),
#  Text(0.36694677871148457, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.37068160597572364, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 22.2'),
#  Text(0.37628384687208216, 0.275, 'X[3] <= 0.5\nsquared_error = 0.007\nsamples = 3\nvalue = 23.1'),
#  Text(0.37441643323996265, 0.225, 'X[6] <= 71.1\nsquared_error = 0.002\nsamples = 2\nvalue = 23.15'),
#  Text(0.37254901960784315, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.37628384687208216, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 23.2'),
#  Text(0.37815126050420167, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.37815126050420167, 0.375, 'X[3] <= 0.5\nsquared_error = 0.562\nsamples = 2\nvalue = 20.95'),
#  Text(0.37628384687208216, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 20.2'),
#  Text(0.3800186741363212, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.3912231559290383, 0.475, 'X[7] <= 3.616\nsquared_error = 1.918\nsamples = 10\nvalue = 19.97'),
#  Text(0.38748832866479926, 0.425, 'X[12] <= 11.69\nsquared_error = 1.524\nsamples = 8\nvalue = 20.388'),
#  Text(0.38562091503267976, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(0.38935574229691877, 0.375, 'X[7] <= 2.746\nsquared_error = 0.627\nsamples = 7\nvalue = 20.014'),
#  Text(0.38748832866479926, 0.325, 'X[0] <= 0.176\nsquared_error = 0.179\nsamples = 6\nvalue = 19.733'),
#  Text(0.38375350140056025, 0.275, 'X[11] <= 390.19\nsquared_error = 0.06\nsamples = 3\nvalue = 20.1'),
#  Text(0.3818860877684407, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 20.4'),
#  Text(0.38562091503267976, 0.225, 'X[7] <= 2.427\nsquared_error = 0.022\nsamples = 2\nvalue = 19.95'),
#  Text(0.38375350140056025, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.38748832866479926, 0.175, 'squared_error = -0.0\nsamples = 1\nvalue = 19.8'),
#  Text(0.3912231559290383, 0.275, 'X[12] <= 12.43\nsquared_error = 0.029\nsamples = 3\nvalue = 19.367'),
#  Text(0.38935574229691877, 0.225, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.3930905695611578, 0.225, 'X[10] <= 21.05\nsquared_error = 0.003\nsamples = 2\nvalue = 19.25'),
#  Text(0.3912231559290383, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.3949579831932773, 0.175, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(0.3912231559290383, 0.325, 'squared_error = -0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.3949579831932773, 0.425, 'X[6] <= 89.45\nsquared_error = 0.01\nsamples = 2\nvalue = 18.3'),
#  Text(0.3930905695611578, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.3968253968253968, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.43388188608776845, 0.775, 'X[9] <= 269.0\nsquared_error = 11.694\nsamples = 55\nvalue = 27.427'),
#  Text(0.39915966386554624, 0.725, 'X[10] <= 17.85\nsquared_error = 5.38\nsamples = 17\nvalue = 30.241'),
#  Text(0.39402427637721754, 0.675, 'X[11] <= 393.41\nsquared_error = 2.699\nsamples = 10\nvalue = 31.71'),
#  Text(0.38935574229691877, 0.625, 'X[11] <= 392.415\nsquared_error = 0.76\nsamples = 5\nvalue = 30.4'),
#  Text(0.38562091503267976, 0.575, 'X[5] <= 6.666\nsquared_error = 0.222\nsamples = 3\nvalue = 29.767'),
#  Text(0.38375350140056025, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 29.1'),
#  Text(0.38748832866479926, 0.525, 'squared_error = -0.0\nsamples = 2\nvalue = 30.1'),
#  Text(0.3930905695611578, 0.575, 'X[1] <= 80.0\nsquared_error = 0.063\nsamples = 2\nvalue = 31.35'),
#  Text(0.3912231559290383, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 31.1'),
#  Text(0.3949579831932773, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.39869281045751637, 0.625, 'X[10] <= 16.25\nsquared_error = 1.206\nsamples = 5\nvalue = 33.02'),
#  Text(0.3968253968253968, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 35.1'),
#  Text(0.4005602240896359, 0.575, 'X[6] <= 30.25\nsquared_error = 0.155\nsamples = 4\nvalue = 32.5'),
#  Text(0.39869281045751637, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 33.1'),
#  Text(0.4024276377217554, 0.525, 'X[7] <= 4.172\nsquared_error = 0.047\nsamples = 3\nvalue = 32.3'),
#  Text(0.4005602240896359, 0.475, 'X[2] <= 4.435\nsquared_error = 0.002\nsamples = 2\nvalue = 32.45'),
#  Text(0.39869281045751637, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 32.5'),
#  Text(0.4024276377217554, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 32.4'),
#  Text(0.4042950513538749, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.4042950513538749, 0.675, 'X[0] <= 0.031\nsquared_error = 1.725\nsamples = 7\nvalue = 28.143'),
#  Text(0.4024276377217554, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 30.8'),
#  Text(0.4061624649859944, 0.625, 'X[11] <= 392.83\nsquared_error = 0.64\nsamples = 6\nvalue = 27.7'),
#  Text(0.4042950513538749, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 26.6'),
#  Text(0.4080298786181139, 0.575, 'X[6] <= 25.65\nsquared_error = 0.053\nsamples = 4\nvalue = 28.25'),
#  Text(0.4061624649859944, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.4098972922502334, 0.525, 'X[6] <= 64.2\nsquared_error = 0.016\nsamples = 3\nvalue = 28.367'),
#  Text(0.4080298786181139, 0.475, 'X[4] <= 0.442\nsquared_error = 0.003\nsamples = 2\nvalue = 28.45'),
#  Text(0.4061624649859944, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 28.5'),
#  Text(0.4098972922502334, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.4117647058823529, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 28.2'),
#  Text(0.46860410830999066, 0.725, 'X[4] <= 0.526\nsquared_error = 9.392\nsamples = 38\nvalue = 26.168'),
#  Text(0.4470121381886088, 0.675, 'X[4] <= 0.436\nsquared_error = 8.024\nsamples = 29\nvalue = 27.007'),
#  Text(0.4276377217553688, 0.625, 'X[6] <= 35.2\nsquared_error = 3.104\nsamples = 11\nvalue = 24.564'),
#  Text(0.4211017740429505, 0.575, 'X[5] <= 6.677\nsquared_error = 1.618\nsamples = 5\nvalue = 26.02'),
#  Text(0.4173669467787115, 0.525, 'X[0] <= 0.029\nsquared_error = 0.023\nsamples = 2\nvalue = 24.65'),
#  Text(0.415499533146592, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.419234360410831, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.42483660130718953, 0.525, 'X[11] <= 395.32\nsquared_error = 0.596\nsamples = 3\nvalue = 26.933'),
#  Text(0.42296918767507, 0.475, 'X[8] <= 4.0\nsquared_error = 0.04\nsamples = 2\nvalue = 26.4'),
#  Text(0.4211017740429505, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.42483660130718953, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 26.2'),
#  Text(0.42670401493930904, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 28.0'),
#  Text(0.4341736694677871, 0.575, 'X[12] <= 8.435\nsquared_error = 1.103\nsamples = 6\nvalue = 23.35'),
#  Text(0.4323062558356676, 0.525, 'X[0] <= 0.044\nsquared_error = 0.287\nsamples = 4\nvalue = 24.025'),
#  Text(0.4304388422035481, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.4341736694677871, 0.475, 'X[10] <= 17.45\nsquared_error = 0.116\nsamples = 3\nvalue = 23.767'),
#  Text(0.4323062558356676, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.43604108309990663, 0.425, 'X[7] <= 8.056\nsquared_error = 0.01\nsamples = 2\nvalue = 24.0'),
#  Text(0.4341736694677871, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.43790849673202614, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 24.1'),
#  Text(0.43604108309990663, 0.525, 'squared_error = -0.0\nsamples = 2\nvalue = 22.0'),
#  Text(0.46638655462184875, 0.625, 'X[12] <= 7.05\nsquared_error = 5.153\nsamples = 18\nvalue = 28.5'),
#  Text(0.45284780578898226, 0.575, 'X[9] <= 301.5\nsquared_error = 1.409\nsamples = 9\nvalue = 30.144'),
#  Text(0.44537815126050423, 0.525, 'X[4] <= 0.477\nsquared_error = 0.367\nsamples = 4\nvalue = 29.075'),
#  Text(0.44164332399626516, 0.475, 'X[2] <= 8.405\nsquared_error = 0.01\nsamples = 2\nvalue = 28.5'),
#  Text(0.43977591036414565, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.44351073762838467, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 28.6'),
#  Text(0.44911297852474324, 0.475, 'X[5] <= 6.703\nsquared_error = 0.063\nsamples = 2\nvalue = 29.65'),
#  Text(0.44724556489262374, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.45098039215686275, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 29.9'),
#  Text(0.4603174603174603, 0.525, 'X[7] <= 4.178\nsquared_error = 0.596\nsamples = 5\nvalue = 31.0'),
#  Text(0.4565826330532213, 0.475, 'X[4] <= 0.471\nsquared_error = 0.062\nsamples = 2\nvalue = 31.75'),
#  Text(0.45471521942110177, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.4584500466853408, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.46405228758169936, 0.475, 'X[0] <= 0.097\nsquared_error = 0.327\nsamples = 3\nvalue = 30.5'),
#  Text(0.46218487394957986, 0.425, 'X[9] <= 384.0\nsquared_error = 0.122\nsamples = 2\nvalue = 30.85'),
#  Text(0.4603174603174603, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.46405228758169936, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 30.5'),
#  Text(0.46591970121381887, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.47992530345471524, 0.575, 'X[7] <= 3.9\nsquared_error = 3.489\nsamples = 9\nvalue = 26.856'),
#  Text(0.4752567693744164, 0.525, 'X[5] <= 6.727\nsquared_error = 1.618\nsamples = 5\nvalue = 28.12'),
#  Text(0.4715219421101774, 0.475, 'X[6] <= 73.65\nsquared_error = 0.303\nsamples = 2\nvalue = 29.55'),
#  Text(0.4696545284780579, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 29.0'),
#  Text(0.4733893557422969, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 30.1'),
#  Text(0.4789915966386555, 0.475, 'X[6] <= 74.5\nsquared_error = 0.222\nsamples = 3\nvalue = 27.167'),
#  Text(0.477124183006536, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 26.5'),
#  Text(0.480859010270775, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 27.5'),
#  Text(0.484593837535014, 0.525, 'X[8] <= 4.5\nsquared_error = 1.332\nsamples = 4\nvalue = 25.275'),
#  Text(0.4827264239028945, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.4864612511671335, 0.475, 'X[11] <= 396.24\nsquared_error = 0.296\nsamples = 3\nvalue = 24.667'),
#  Text(0.484593837535014, 0.425, 'X[10] <= 18.55\nsquared_error = 0.003\nsamples = 2\nvalue = 25.05'),
#  Text(0.4827264239028945, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 25.1'),
#  Text(0.4864612511671335, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.488328664799253, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.49019607843137253, 0.675, 'X[10] <= 17.1\nsquared_error = 4.233\nsamples = 9\nvalue = 23.467'),
#  Text(0.48552754435107376, 0.625, 'X[4] <= 0.544\nsquared_error = 5.522\nsamples = 2\nvalue = 26.35'),
#  Text(0.48366013071895425, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 24.0'),
#  Text(0.48739495798319327, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.49486461251167135, 0.625, 'X[10] <= 20.6\nsquared_error = 0.811\nsamples = 7\nvalue = 22.643'),
#  Text(0.4911297852474323, 0.575, 'X[7] <= 3.325\nsquared_error = 0.227\nsamples = 4\nvalue = 23.275'),
#  Text(0.4892623716153128, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 22.8'),
#  Text(0.49299719887955185, 0.525, 'X[6] <= 81.1\nsquared_error = 0.002\nsamples = 2\nvalue = 23.75'),
#  Text(0.4911297852474323, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 23.7'),
#  Text(0.49486461251167135, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 23.8'),
#  Text(0.49859943977591037, 0.575, 'X[2] <= 10.035\nsquared_error = 0.347\nsamples = 3\nvalue = 21.8'),
#  Text(0.49673202614379086, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.5004668534080299, 0.525, 'X[0] <= 0.086\nsquared_error = 0.04\nsamples = 2\nvalue = 22.2'),
#  Text(0.49859943977591037, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.5023342670401494, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.6638035422502334, 0.875, 'X[0] <= 6.992\nsquared_error = 19.276\nsamples = 175\nvalue = 14.956'),
#  Text(0.5840846755368814, 0.825, 'X[4] <= 0.531\nsquared_error = 11.391\nsamples = 101\nvalue = 17.138'),
#  Text(0.5287114845938375, 0.775, 'X[7] <= 5.57\nsquared_error = 9.016\nsamples = 24\nvalue = 20.021'),
#  Text(0.5154061624649859, 0.725, 'X[6] <= 88.55\nsquared_error = 2.862\nsamples = 13\nvalue = 21.454'),
#  Text(0.5079365079365079, 0.675, 'X[11] <= 385.375\nsquared_error = 0.792\nsamples = 6\nvalue = 22.967'),
#  Text(0.5042016806722689, 0.625, 'X[12] <= 22.105\nsquared_error = 0.122\nsamples = 2\nvalue = 24.05'),
#  Text(0.5023342670401494, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 24.4'),
#  Text(0.5060690943043884, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 23.7'),
#  Text(0.5116713352007469, 0.625, 'X[4] <= 0.517\nsquared_error = 0.247\nsamples = 4\nvalue = 22.425'),
#  Text(0.5098039215686274, 0.575, 'X[7] <= 3.124\nsquared_error = 0.096\nsamples = 3\nvalue = 22.667'),
#  Text(0.5079365079365079, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.5116713352007469, 0.525, 'X[3] <= 0.5\nsquared_error = 0.002\nsamples = 2\nvalue = 22.45'),
#  Text(0.5098039215686274, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.5135387488328664, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.5135387488328664, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 21.7'),
#  Text(0.5228758169934641, 0.675, 'X[5] <= 5.905\nsquared_error = 0.994\nsamples = 7\nvalue = 20.157'),
#  Text(0.5191409897292251, 0.625, 'X[6] <= 98.35\nsquared_error = 0.067\nsamples = 4\nvalue = 19.575'),
#  Text(0.5172735760971056, 0.575, 'X[8] <= 4.5\nsquared_error = 0.009\nsamples = 3\nvalue = 19.433'),
#  Text(0.5154061624649859, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.5191409897292251, 0.525, 'squared_error = 0.0\nsamples = 2\nvalue = 19.5'),
#  Text(0.5210084033613446, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(0.5266106442577031, 0.625, 'X[7] <= 2.797\nsquared_error = 1.176\nsamples = 3\nvalue = 20.933'),
#  Text(0.5247432306255836, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 19.4'),
#  Text(0.5284780578898226, 0.575, 'squared_error = 0.0\nsamples = 2\nvalue = 21.7'),
#  Text(0.542016806722689, 0.725, 'X[0] <= 0.157\nsquared_error = 10.993\nsamples = 11\nvalue = 18.327'),
#  Text(0.5359477124183006, 0.675, 'X[4] <= 0.48\nsquared_error = 12.827\nsamples = 3\nvalue = 22.1'),
#  Text(0.5340802987861811, 0.625, 'X[10] <= 18.55\nsquared_error = 0.49\nsamples = 2\nvalue = 19.6'),
#  Text(0.5322128851540616, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.5359477124183006, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 18.9'),
#  Text(0.5378151260504201, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.5480859010270775, 0.675, 'X[6] <= 89.65\nsquared_error = 2.966\nsamples = 8\nvalue = 16.912'),
# ...
#  Text(0.8057889822595705, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.8095238095238095, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 6.3'),
#  Text(0.8300653594771242, 0.625, 'X[7] <= 1.589\nsquared_error = 2.76\nsamples = 19\nvalue = 8.053'),
#  Text(0.8179271708683473, 0.575, 'X[5] <= 4.826\nsquared_error = 3.204\nsamples = 8\nvalue = 7.088'),
#  Text(0.8132586367880486, 0.525, 'X[6] <= 95.6\nsquared_error = 0.722\nsamples = 2\nvalue = 9.65'),
#  Text(0.811391223155929, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 8.8'),
#  Text(0.8151260504201681, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 10.5'),
#  Text(0.8225957049486461, 0.525, 'X[0] <= 23.822\nsquared_error = 1.112\nsamples = 6\nvalue = 6.233'),
#  Text(0.8188608776844071, 0.475, 'X[6] <= 93.8\nsquared_error = 0.009\nsamples = 3\nvalue = 7.267'),
#  Text(0.8169934640522876, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 7.4'),
#  Text(0.8207282913165266, 0.425, 'squared_error = -0.0\nsamples = 2\nvalue = 7.2'),
#  Text(0.8263305322128851, 0.475, 'X[5] <= 5.835\nsquared_error = 0.08\nsamples = 3\nvalue = 5.2'),
#  Text(0.8244631185807656, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.8281979458450047, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.842203548085901, 0.575, 'X[11] <= 107.815\nsquared_error = 1.268\nsamples = 11\nvalue = 8.755'),
#  Text(0.8375350140056023, 0.525, 'X[11] <= 21.85\nsquared_error = 0.499\nsamples = 6\nvalue = 8.067'),
#  Text(0.8338001867413632, 0.475, 'X[11] <= 8.5\nsquared_error = 0.047\nsamples = 3\nvalue = 8.6'),
#  Text(0.8319327731092437, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.8356676003734828, 0.425, 'X[12] <= 23.535\nsquared_error = 0.002\nsamples = 2\nvalue = 8.75'),
#  Text(0.8338001867413632, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.8'),
#  Text(0.8375350140056023, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.7'),
#  Text(0.8412698412698413, 0.475, 'X[0] <= 15.881\nsquared_error = 0.382\nsamples = 3\nvalue = 7.533'),
#  Text(0.8394024276377218, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 8.4'),
#  Text(0.8431372549019608, 0.425, 'X[0] <= 31.915\nsquared_error = 0.01\nsamples = 2\nvalue = 7.1'),
#  Text(0.8412698412698413, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.2'),
#  Text(0.8450046685340803, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.8468720821661998, 0.525, 'X[12] <= 20.94\nsquared_error = 0.942\nsamples = 5\nvalue = 9.58'),
#  Text(0.8450046685340803, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.8487394957983193, 0.475, 'X[6] <= 87.25\nsquared_error = 0.665\nsamples = 4\nvalue = 9.9'),
#  Text(0.8468720821661998, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 8.5'),
#  Text(0.8506069094304388, 0.425, 'X[12] <= 28.63\nsquared_error = 0.016\nsamples = 3\nvalue = 10.367'),
#  Text(0.8487394957983193, 0.375, 'X[6] <= 90.75\nsquared_error = 0.002\nsamples = 2\nvalue = 10.45'),
#  Text(0.8468720821661998, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8506069094304388, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 10.5'),
#  Text(0.8524743230625583, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 10.2'),
#  Text(0.9390756302521008, 0.925, 'X[5] <= 7.437\nsquared_error = 79.729\nsamples = 76\nvalue = 37.238'),
#  Text(0.9105975723622782, 0.875, 'X[4] <= 0.659\nsquared_error = 41.296\nsamples = 46\nvalue = 32.113'),
#  Text(0.8898225957049486, 0.825, 'X[7] <= 1.886\nsquared_error = 20.111\nsamples = 43\nvalue = 33.349'),
#  Text(0.8753501400560224, 0.775, 'X[5] <= 6.979\nsquared_error = 18.923\nsamples = 2\nvalue = 45.65'),
#  Text(0.8734827264239029, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 41.3'),
#  Text(0.8772175536881419, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9042950513538749, 0.775, 'X[4] <= 0.488\nsquared_error = 12.427\nsamples = 41\nvalue = 32.749'),
#  Text(0.8809523809523809, 0.725, 'X[6] <= 11.95\nsquared_error = 5.014\nsamples = 27\nvalue = 34.156'),
#  Text(0.8725490196078431, 0.675, 'X[2] <= 4.05\nsquared_error = 0.09\nsamples = 2\nvalue = 29.3'),
#  Text(0.8706816059757236, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 29.0'),
#  Text(0.8744164332399627, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.8893557422969187, 0.675, 'X[12] <= 5.44\nsquared_error = 3.371\nsamples = 25\nvalue = 34.544'),
#  Text(0.8781512605042017, 0.625, 'X[0] <= 0.049\nsquared_error = 2.397\nsamples = 16\nvalue = 35.306'),
#  Text(0.8683473389355743, 0.575, 'X[12] <= 4.505\nsquared_error = 0.88\nsamples = 8\nvalue = 34.363'),
#  Text(0.8636788048552755, 0.525, 'X[2] <= 2.565\nsquared_error = 0.646\nsamples = 5\nvalue = 33.84'),
#  Text(0.8599439775910365, 0.475, 'X[7] <= 7.481\nsquared_error = 0.047\nsamples = 3\nvalue = 33.2'),
#  Text(0.8580765639589168, 0.425, 'X[2] <= 1.85\nsquared_error = 0.003\nsamples = 2\nvalue = 33.35'),
#  Text(0.8562091503267973, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 33.3'),
#  Text(0.8599439775910365, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 33.4'),
#  Text(0.861811391223156, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 32.9'),
#  Text(0.8674136321195145, 0.475, 'X[0] <= 0.03\nsquared_error = 0.01\nsamples = 2\nvalue = 34.8'),
#  Text(0.865546218487395, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 34.7'),
#  Text(0.869281045751634, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.873015873015873, 0.525, 'X[8] <= 4.0\nsquared_error = 0.056\nsamples = 3\nvalue = 35.233'),
#  Text(0.8711484593837535, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.8748832866479925, 0.475, 'X[11] <= 394.08\nsquared_error = 0.0\nsamples = 2\nvalue = 35.4'),
#  Text(0.873015873015873, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 35.4'),
#  Text(0.876750700280112, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 35.4'),
#  Text(0.8879551820728291, 0.575, 'X[8] <= 6.0\nsquared_error = 2.133\nsamples = 8\nvalue = 36.25'),
#  Text(0.8860877684407096, 0.525, 'X[12] <= 5.36\nsquared_error = 0.817\nsamples = 7\nvalue = 36.7'),
#  Text(0.8842203548085901, 0.475, 'X[7] <= 5.589\nsquared_error = 0.323\nsamples = 6\nvalue = 37.0'),
#  Text(0.880485527544351, 0.425, 'X[5] <= 7.151\nsquared_error = 0.096\nsamples = 3\nvalue = 37.467'),
#  Text(0.8786181139122315, 0.375, 'X[9] <= 219.0\nsquared_error = 0.003\nsamples = 2\nvalue = 37.25'),
#  Text(0.876750700280112, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 37.2'),
#  Text(0.880485527544351, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 37.3'),
#  Text(0.8823529411764706, 0.375, 'squared_error = -0.0\nsamples = 1\nvalue = 37.9'),
#  Text(0.8879551820728291, 0.425, 'X[0] <= 0.089\nsquared_error = 0.116\nsamples = 3\nvalue = 36.533'),
#  Text(0.8860877684407096, 0.375, 'X[5] <= 7.162\nsquared_error = 0.01\nsamples = 2\nvalue = 36.3'),
#  Text(0.8842203548085901, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 36.2'),
#  Text(0.8879551820728291, 0.325, 'squared_error = 0.0\nsamples = 1\nvalue = 36.4'),
#  Text(0.8898225957049486, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 37.0'),
#  Text(0.8879551820728291, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 34.9'),
#  Text(0.8898225957049486, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 33.1'),
#  Text(0.9005602240896359, 0.625, 'X[6] <= 37.45\nsquared_error = 2.234\nsamples = 9\nvalue = 33.189'),
#  Text(0.8954248366013072, 0.575, 'X[1] <= 85.0\nsquared_error = 0.903\nsamples = 2\nvalue = 31.25'),
#  Text(0.8935574229691877, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 30.3'),
#  Text(0.8972922502334267, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 32.2'),
#  Text(0.9056956115779645, 0.575, 'X[6] <= 45.05\nsquared_error = 1.234\nsamples = 7\nvalue = 33.743'),
#  Text(0.9010270774976658, 0.525, 'X[5] <= 7.255\nsquared_error = 0.562\nsamples = 2\nvalue = 35.35'),
#  Text(0.8991596638655462, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 36.1'),
#  Text(0.9028944911297853, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 34.6'),
#  Text(0.9103641456582633, 0.525, 'X[0] <= 0.044\nsquared_error = 0.056\nsamples = 5\nvalue = 33.1'),
#  Text(0.9066293183940243, 0.475, 'X[4] <= 0.429\nsquared_error = 0.022\nsamples = 2\nvalue = 32.85'),
#  Text(0.9047619047619048, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 33.0'),
#  Text(0.9084967320261438, 0.425, 'squared_error = -0.0\nsamples = 1\nvalue = 32.7'),
#  Text(0.9140989729225023, 0.475, 'X[7] <= 3.297\nsquared_error = 0.009\nsamples = 3\nvalue = 33.267'),
#  Text(0.9122315592903828, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 33.4'),
#  Text(0.9159663865546218, 0.425, 'squared_error = 0.0\nsamples = 2\nvalue = 33.2'),
#  Text(0.9276377217553688, 0.725, 'X[5] <= 7.121\nsquared_error = 15.547\nsamples = 14\nvalue = 30.036'),
#  Text(0.9197012138188608, 0.675, 'X[4] <= 0.594\nsquared_error = 7.09\nsamples = 7\nvalue = 26.914'),
#  Text(0.9159663865546218, 0.625, 'X[0] <= 0.055\nsquared_error = 3.614\nsamples = 5\nvalue = 25.58'),
#  Text(0.9140989729225023, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 28.7'),
#  Text(0.9178338001867413, 0.575, 'X[5] <= 6.964\nsquared_error = 1.475\nsamples = 4\nvalue = 24.8'),
#  Text(0.9159663865546218, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 26.7'),
#  Text(0.9197012138188608, 0.525, 'X[6] <= 81.65\nsquared_error = 0.362\nsamples = 3\nvalue = 24.167'),
#  Text(0.9178338001867413, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.9215686274509803, 0.475, 'X[9] <= 271.5\nsquared_error = 0.023\nsamples = 2\nvalue = 23.75'),
#  Text(0.9197012138188608, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.9234360410831, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 23.9'),
#  Text(0.9234360410831, 0.625, 'X[7] <= 2.333\nsquared_error = 0.203\nsamples = 2\nvalue = 30.25'),
#  Text(0.9215686274509803, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.9253034547152195, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.9355742296918768, 0.675, 'X[7] <= 2.004\nsquared_error = 4.517\nsamples = 7\nvalue = 33.157'),
#  Text(0.930905695611578, 0.625, 'X[6] <= 95.8\nsquared_error = 0.062\nsamples = 2\nvalue = 36.25'),
#  Text(0.9290382819794585, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 36.5'),
#  Text(0.9327731092436975, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 36.0'),
#  Text(0.9402427637721755, 0.625, 'X[5] <= 7.265\nsquared_error = 0.942\nsamples = 5\nvalue = 31.92'),
#  Text(0.9365079365079365, 0.575, 'X[1] <= 10.0\nsquared_error = 1.21\nsamples = 2\nvalue = 32.7'),
#  Text(0.934640522875817, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.938375350140056, 0.525, 'squared_error = -0.0\nsamples = 1\nvalue = 33.8'),
#  Text(0.9439775910364145, 0.575, 'X[5] <= 7.342\nsquared_error = 0.087\nsamples = 3\nvalue = 31.4'),
#  Text(0.942110177404295, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 31.0'),
#  Text(0.945845004668534, 0.525, 'X[4] <= 0.506\nsquared_error = 0.01\nsamples = 2\nvalue = 31.6'),
#  Text(0.9439775910364145, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 31.7'),
#  Text(0.9477124183006536, 0.475, 'squared_error = -0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.9313725490196079, 0.825, 'X[5] <= 7.141\nsquared_error = 9.307\nsamples = 3\nvalue = 14.4'),
#  Text(0.9295051353874884, 0.775, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.9332399626517274, 0.775, 'X[11] <= 386.385\nsquared_error = 1.96\nsamples = 2\nvalue = 16.4'),
#  Text(0.9313725490196079, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.9351073762838469, 0.725, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.9675536881419234, 0.875, 'X[10] <= 19.65\nsquared_error = 36.628\nsamples = 30\nvalue = 45.097'),
#  Text(0.9656862745098039, 0.825, 'X[10] <= 14.8\nsquared_error = 18.697\nsamples = 29\nvalue = 45.897'),
#  Text(0.9533146591970122, 0.775, 'X[5] <= 7.706\nsquared_error = 8.027\nsamples = 14\nvalue = 48.3'),
#  Text(0.9495798319327731, 0.725, 'X[0] <= 1.002\nsquared_error = 9.462\nsamples = 4\nvalue = 44.725'),
#  Text(0.9477124183006536, 0.675, 'X[2] <= 3.0\nsquared_error = 0.249\nsamples = 3\nvalue = 42.967'),
#  Text(0.945845004668534, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 42.3'),
#  Text(0.9495798319327731, 0.625, 'X[4] <= 0.611\nsquared_error = 0.04\nsamples = 2\nvalue = 43.3'),
#  Text(0.9477124183006536, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 43.5'),
#  Text(0.9514472455648926, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 43.1'),
#  Text(0.9514472455648926, 0.675, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9570494864612512, 0.725, 'X[12] <= 3.755\nsquared_error = 0.296\nsamples = 10\nvalue = 49.73'),
#  Text(0.9551820728291317, 0.675, 'squared_error = 0.0\nsamples = 6\nvalue = 50.0'),
#  Text(0.9589169000933707, 0.675, 'X[0] <= 0.549\nsquared_error = 0.467\nsamples = 4\nvalue = 49.325'),
#  Text(0.9570494864612512, 0.625, 'X[6] <= 62.35\nsquared_error = 0.023\nsamples = 2\nvalue = 48.65'),
#  Text(0.9551820728291317, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 48.5'),
#  Text(0.9589169000933707, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 48.8'),
#  Text(0.9607843137254902, 0.625, 'squared_error = -0.0\nsamples = 2\nvalue = 50.0'),
#  Text(0.9780578898225957, 0.775, 'X[11] <= 385.48\nsquared_error = 18.232\nsamples = 15\nvalue = 43.653'),
#  Text(0.9701213818860878, 0.725, 'X[0] <= 0.323\nsquared_error = 3.298\nsamples = 5\nvalue = 47.16'),
#  Text(0.9663865546218487, 0.675, 'X[11] <= 381.28\nsquared_error = 0.616\nsamples = 3\nvalue = 45.833'),
#  Text(0.9645191409897292, 0.625, 'X[4] <= 0.473\nsquared_error = 0.122\nsamples = 2\nvalue = 46.35'),
#  Text(0.9626517273576097, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 46.0'),
#  Text(0.9663865546218487, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 46.7'),
#  Text(0.9682539682539683, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 44.8'),
#  Text(0.9738562091503268, 0.675, 'X[7] <= 3.273\nsquared_error = 0.722\nsamples = 2\nvalue = 49.15'),
#  Text(0.9719887955182073, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9757236227824463, 0.625, 'squared_error = -0.0\nsamples = 1\nvalue = 48.3'),
#  Text(0.9859943977591037, 0.725, 'X[0] <= 0.061\nsquared_error = 16.476\nsamples = 10\nvalue = 41.9'),
#  Text(0.9813258636788048, 0.675, 'X[5] <= 7.826\nsquared_error = 6.569\nsamples = 3\nvalue = 46.467'),
#  Text(0.9794584500466853, 0.625, 'X[7] <= 5.515\nsquared_error = 0.49\nsamples = 2\nvalue = 44.7'),
#  Text(0.9775910364145658, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 45.4'),
#  Text(0.9813258636788048, 0.575, 'squared_error = -0.0\nsamples = 1\nvalue = 44.0'),
#  Text(0.9831932773109243, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.9906629318394025, 0.675, 'X[6] <= 44.35\nsquared_error = 7.954\nsamples = 7\nvalue = 39.943'),
#  Text(0.9869281045751634, 0.625, 'X[9] <= 303.0\nsquared_error = 0.25\nsamples = 2\nvalue = 43.3'),
#  Text(0.9850606909430439, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 43.8'),
#  Text(0.988795518207283, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 42.8'),
#  Text(0.9943977591036415, 0.625, 'X[6] <= 62.55\nsquared_error = 4.724\nsamples = 5\nvalue = 38.6'),
#  Text(0.992530345471522, 0.575, 'squared_error = 0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.996265172735761, 0.575, 'X[5] <= 8.203\nsquared_error = 2.293\nsamples = 4\nvalue = 39.45'),
#  Text(0.9943977591036415, 0.525, 'X[8] <= 5.5\nsquared_error = 0.807\nsamples = 3\nvalue = 38.7'),
#  Text(0.992530345471522, 0.475, 'X[11] <= 396.23\nsquared_error = 0.303\nsamples = 2\nvalue = 39.25'),
#  Text(0.9906629318394025, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 39.8'),
#  Text(0.9943977591036415, 0.425, 'squared_error = 0.0\nsamples = 1\nvalue = 38.7'),
#  Text(0.996265172735761, 0.475, 'squared_error = 0.0\nsamples = 1\nvalue = 37.6'),
#  Text(0.9981325863678805, 0.525, 'squared_error = 0.0\nsamples = 1\nvalue = 41.7'),
#  Text(0.969421101774043, 0.825, 'squared_error = -0.0\nsamples = 1\nvalue = 21.9')]

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz(decision_tree=model, feature_names=boston.feature_names, filled=True, rounded=True, special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# #### 시각화

# %% [markdown]
# ##### 회귀식 시각화

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([0,1,2]):
    X = boston.data[:,pair].reshape(-1,1)
    y = boston.target
    
    model = DecisionTreeRegressor()
    model = model.fit(X,y)
    
    X_test = np.arange(min(X),max(X),0.1)[:,np.newaxis]
    predict = model.predict(X_test)
    
    plt.subplot(1,3,pairidx+1)
    plt.scatter(X,y,s=20,edgecolors='b',c='darkorange',label='data')
    plt.plot(X_test, predict, color='skyblue', linewidth=2)
    plt.xlabel(boston.feature_names[pair])
    plt.ylabel('Target')

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 회귀식 시각화

# %%
plt.figure(figsize=(16,8))

for pairidx, pair in enumerate([0,1,2]):
    X = boston.data[:,pair].reshape(-1,1)
    y = boston.target
    
    model = DecisionTreeRegressor(max_depth=3)
    model = model.fit(X,y)
    
    X_test = np.arange(min(X),max(X),0.1)[:,np.newaxis]
    predict = model.predict(X_test)
    
    plt.subplot(1,3,pairidx+1)
    plt.scatter(X,y,s=20,edgecolors='b',c='darkorange',label='data')
    plt.plot(X_test, predict, color='skyblue', linewidth=2)
    plt.xlabel(boston.feature_names[pair])
    plt.ylabel('Target')

# %% [markdown]
# ### 당뇨병 데이터 학습

# %% [markdown]
# #### 교차 검증

# %% [markdown]
# ##### 전처리 없이 학습

# %% [markdown]
# ##### 전처리 후 학습

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %% [markdown]
# ##### 텍스트를 통한 시각화

# %% [markdown]
# ##### plot_tree를 사용한 시각화

# %% [markdown]
# ##### graphviz를 사용한 시각화

# %% [markdown]
# #### 시각화

# %% [markdown]
# ##### 회귀식 시각화

# %% [markdown]
# ##### 하이퍼파리미터를 변경해 보면서 회귀식 시각화
